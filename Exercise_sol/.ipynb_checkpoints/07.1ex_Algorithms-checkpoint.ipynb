# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that they are two procedure yields to same result
# * What percent of the total variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
import numpy as np
from scipy import linalg as la
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# Generate a dataset with 3 features each with N entries
N = 2000
sigma = 3

x1 = np.random.randn(N)
x2 = x1+sigma*np.random.randn(N)
x3 = 2*x1+x2

dtst = np.vstack((x1,x2,x3))

# Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
covmat=np.cov(dtst)
print("Covariance matrix:\n", covmat)
e, V = la.eig(covmat)
print("\nEigenvalues of the covariance matrix:\n", e)
print("\nEigenvectors of the covariance matrix:\n", V)

# Find the eigenvectors and eigenvalues using SVD
U, S, Vt = la.svd(dtst)
SVD_eig = S**2/(N-1)
print("\nEigenvalues of the covariance matrix SVD:\n", SVD_eig)
print("\nEigenvectors of the covariance matrix SVD:\n", U)


# Reduce the dimensionality of the system so that at least 99% of the total variability is retained
variab=((SVD_eig[0]+SVD_eig[1])/SVD_eig.sum())
print("\nVariability:", variab)
# All the variability come from the first two eigenvectors, this is probably due to the fact that x3 is a linear combination of x1 and x2

# Redefine the data in the basis yielded by the PCA procedure
new_dtst = U.T.dot(dtst)

# Plot the data points in the original and the new coordiantes as a set of scatter plots
# Original basis
plt.figure(figsize=(18, 10))
ax1 = plt.subplot(2, 3, 1)
ax1.scatter(dtst[0,:], dtst[1,:], alpha=0.3)
ax1.set_title('Original basis: 0 and 1')
ax1.set_ylim(-20, 20)
ax1.set_xlim(-20, 20)

ax2 = plt.subplot(2,3,2)
ax2.scatter(dtst[0,:], dtst[2,:], alpha=0.3)
ax2.set_title('Original basis: 0 and 2')
ax2.set_ylim(-20, 20)
ax2.set_xlim(-20, 20)

ax3 = plt.subplot(2,3,3)
ax3.scatter(dtst[1,:], dtst[2,:], alpha=0.3)
ax3.set_title('Original basis: 1 and 2')
ax3.set_ylim(-20, 20)
ax3.set_xlim(-20, 20)

# New basis
ax4 = plt.subplot(2,3,4)
ax4.scatter(new_dtst[0,:], new_dtst[1,:], alpha=0.3)
ax4.set_title('New basis: 0 and 1')
ax4.set_ylim(-20, 20)
ax4.set_xlim(-20, 20)

ax5 = plt.subplot(2,3,5)
ax5.scatter(new_dtst[0,:], new_dtst[2,:], alpha=0.3)
ax5.set_title('New basis: 0 and 2')
ax5.set_ylim(-20, 20)
ax5.set_xlim(-20, 20)

ax6 = plt.subplot(2,3,6)
ax6.scatter(new_dtst[1,:], new_dtst[2,:], alpha=0.3)
ax6.set_title('New basis: 1 and 2')
ax6.set_ylim(-20, 20)
ax6.set_xlim(-20, 20)

plt.show()
# Out:
# Covariance matrix:
#  [[ 1.02193955  0.9585562   3.00243531]
#  [ 0.9585562  10.06943635 11.98654876]
#  [ 3.00243531 11.98654876 17.99141938]]
#
# Eigenvalues of the covariance matrix:
#  [2.70002537e+01+0.j 2.87821967e-16+0.j 2.08254160e+00+0.j]
#
# Eigenvectors of the covariance matrix:
#  [[-0.11468939 -0.81649658  0.56584422]
#  [-0.57832541 -0.40824829 -0.70630946]
#  [-0.80770419  0.40824829  0.42537897]]
#
# Eigenvalues of the covariance matrix SVD:
#  [2.70006310e+01 2.08355148e+00 9.66284462e-32]
#
# Eigenvectors of the covariance matrix SVD:
#  [[-0.11467537  0.56584706 -0.81649658]
#  [-0.57834291 -0.70629513 -0.40824829]
#  [-0.80769365  0.42539898  0.40824829]]
#
# Variability: 1.0

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
dtst_noisy = dtst
for i in range(10):
    xNoise = (np.random.uniform(low=1.0, high=sigma)/50*np.random.randn(N))
    dtst_noisy = np.vstack((dtst_noisy,xNoise))
    
U, S, Vt = la.svd(dtst_noisy)
SVD_eig = S**2/(N-1)
print("\nEigenvalues:\n", SVD_eig)

variab=((SVD_eig[0]+SVD_eig[1])/SVD_eig.sum())
print("\nVariability:", variab)

new_dtst_noisy = U.T.dot(dtst_noisy)

c = 1
plt.figure(figsize=(18, 100))
for i in range(10):
    for j in range(i+1,11):
        ax = plt.subplot(19, 3, c)
        ax.scatter(new_dtst_noisy[i,:],new_dtst_noisy[j,:], alpha=0.3)
        ax.axis([-20, 20, -20, 20])
        ax.set_title("Noisy dataset new basis: "+str(i)+" and "+str(j))
        c = c + 1
        
plt.show()
# Out:
# Eigenvalues:
#  [2.70006354e+01 2.08356229e+00 2.25280937e-03 1.25382650e-03
#  1.15058973e-03 1.10086791e-03 9.68215987e-04 8.40292726e-04
#  7.72376509e-04 7.14999351e-04 5.70599230e-04 5.12247919e-04
#  9.71926952e-32]
#
# Variability: 0.9996515876573613

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %%
N = 10000
t = np.linspace(0,2*np.pi,N)
pos = np.cos(t)
noise = np.random.normal(loc=0, scale=0.1, size=N) # Little noise
spring_coordinates = np.vstack((np.vstack((pos,noise)),np.zeros(N)))

# Spherical coord
samples = 3
cameras_theta = np.linspace(0,np.pi/2,samples)
cameras_phi = np.linspace(0,np.pi/2,samples)
cameras_coord = np.zeros((samples**2,2))
rotated_spring = np.zeros((samples**2,N,3))

# Rotate the data
i = 0
for theta in cameras_theta:
    for phi in cameras_phi:
        z_rotation = np.array([[np.cos(theta), np.sin(theta), 0], [-np.sin(theta), np.cos(theta), 0], [0, 0, 1]])
        y_rotation = np.array([[np.cos(phi), 0, np.sin(phi)], [0, 1, 0], [-np.sin(phi), 0, np.cos(phi)]])
        rotation = z_rotation.dot(y_rotation)
        
        rotated_spring[i] = rotation.dot(spring_coordinates).T
        cameras_coord[i] = np.array([theta, phi])
        i = i+1

# Plot
rows = np.ceil(samples**2)
plt.figure(figsize = (12,6*rows))
for k in range(1,samples**2+1):
    plt.subplot(rows,2,k)
    plt.scatter(rotated_spring[k-1,:,0],rotated_spring[k-1,:,1])
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim(-1.2, 1.2)
    plt.ylim(-1.2, 1.2)
    plt.title("Tetha = "+str(round(cameras_coord[k-1,0],2))+" ,Phi = "+str(round(cameras_coord[k-1,1],2)),fontsize=15, verticalalignment='bottom')

# PCA
U, spectrum, Vt = np.linalg.svd(rotated_spring)
l_svd = spectrum**2/(N-1)
variability = l_svd/np.sum(l_svd)

print('Variability per each principal component:\n',variability)

plt.show()
# Out:
# Variability per each principal component:
#  [[1.08909909e-01 2.20120176e-03 0.00000000e+00]
#  [1.08909909e-01 2.20120176e-03 1.67715659e-35]
#  [1.08909909e-01 2.20120176e-03 1.36975356e-64]
#  [1.08909909e-01 2.20120176e-03 0.00000000e+00]
#  [1.08909909e-01 2.20120176e-03 1.34137205e-32]
#  [1.08909909e-01 2.20120176e-03 3.23610935e-35]
#  [1.08909909e-01 2.20120176e-03 0.00000000e+00]
#  [1.08909909e-01 2.20120176e-03 8.18232231e-34]
#  [1.08909909e-01 2.20120176e-03 1.34162095e-65]]

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# Load csv
data = pd.read_csv('magic04.data', names=['fLength','fWidth','fSize','fConc','fConc1','fAsym','fM3Long','fM3Trans','fAlpha','fDist','fCategory'])

# Transform chars in number
data.loc[data['fCategory'] =='g', 'fCategory'] = 0
data.loc[data['fCategory'] =='h', 'fCategory'] = 1

# Compute covariance
data_cov = np.cov(data.T)
U, spectrum, Vt = la.svd(data_cov)
eigs_sum = np.sum(spectrum)
print("Trace of covariance matrix:",data_cov.trace()) 
print("Sum of all the eigenvalues:",eigs_sum)

# PCA
print ("\nVariability per each principal component:\n",spectrum/eigs_sum)
print ("\nVariability with the first three eigenvalues:\n",np.sum(spectrum[:4])/eigs_sum)
# Out:
# Trace of covariance matrix: 14938.246709706402
# Sum of all the eigenvalues: 14938.246709706398
#
# Variability per each principal component:
#  [4.40466498e-01 2.57987592e-01 1.34981328e-01 8.88172454e-02
#  4.08498986e-02 2.90261107e-02 7.85438231e-03 1.04326075e-05
#  5.77816391e-06 7.09203170e-07 2.57395320e-08]
#
# Variability with the first three eigenvalues:
#  0.9222526627260887
