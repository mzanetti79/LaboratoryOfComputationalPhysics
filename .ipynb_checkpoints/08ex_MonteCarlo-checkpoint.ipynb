# %%
import numpy as np
import pandas as pd
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %precision 4
# Out:
# '%.4f'

# %% [markdown]
# 1\. **Radioactive decay chain**
#
# ${\rm Tl}^{208}$ decays to ${\rm Pb}^{208}$ with a half-lieve of 3.052 minutes. Suppose to start with a sample of 1000 Thallium atoms and 0 of Lead atoms.
#
# * Take steps in time of 1 second and at each time-step decide whether each Tl atom has decayed or not, accordingly to the probability $p(t)=1-2^{-t/\tau}$. Subtract the total number of Tl atoms that decayed at each step from the Tl sample and add them to the Lead one. Plot the evolution of the two sets as a function of time
# * Repeat the exercise by means of the inverse transform method: draw 1000 random numbers from the non-uniform probability distribution $p(t)=2^{-t/\tau}\frac{\ln 2}{\tau}$ to represent the times of decay of the 1000 Tl atoms. Make a plot showing the number of atoms that have not decayed as a function of time

# %%
#first method
Tl_initial=1000
Pb_initial=0
step=1 #sec
half_life= 3.052*60 #in secondi
#tau= half_life/np.log(2)
tot_time=183
print(half_life)
Tl_over_time=np.zeros(0)
Tl_over_time=np.append(Tl_over_time,Tl_initial)
Pb_over_time=np.zeros(0)
Pb_over_time=np.append(Pb_over_time,Pb_initial)
def prob_decay(t,mu=1/half_life):
    return 1-np.power(2,-mu*t)

x=np.arange(tot_time)
y=prob_decay(x)
plt.plot(x,y)
#for i in range(tot_time):
    
#print(prob_decay(half_life))
#print(np.log(2))
# dopo una half life mi devono essere rimasti circa meta atomi di Tl
for i in range(tot_time):
    Tl_not_decayed =Tl_initial-Tl_initial*prob_decay(i)
    Pb_in_the_set= Pb_initial + Tl_initial*prob_decay(i)
    Tl_over_time= np.append(Tl_over_time, Tl_not_decayed)
    Pb_over_time= np.append(Pb_over_time, Pb_in_the_set)
    

plt.figure(figsize=(12,4))
plt.plot(range(tot_time+1), Tl_over_time,range(tot_time+1), Pb_over_time)
plt.legend(('Tl$^{208}$', 'Pb$^{208}$'), loc='best')
plt.xlabel('Time [s]')
plt.ylabel('Number of atoms')
plt.title('Evolution over time')
#plt.plot(range(tot_time+1), Tl_over_time)
#print(Tl_over_time)
# Out:
# 183.12
# Text(0.5,1,'Evolution over time')

# %%
#inverse transform method
half_life= 3.052
#tau= half_life/np.log(2)
def expon_pdf(t, mu=1/half_life):
    """PDF of exponential distribution."""
    return np.power(2,-mu*t)*np.log(2)*mu

def expon_cdf(t, mu=1/half_life):
    """CDF of exponetial distribution."""
    return 1 - np.power(2,-mu*t)

def expon_icdf(p, mu=1/half_life):
    """Inverse CDF of exponential distribution - i.e. quantile function."""
    return -np.log2(1-p)/mu

plt.plot(np.arange(184), expon_pdf(np.arange(184)))

# %%
Tl_initial=1000
Pb_initial=0
half_life= 3.052*60 #in secondi
tot_time=183
Tl_over_time=np.zeros(0)
Tl_over_time=np.append(Tl_over_time,Tl_initial)
Pb_over_time=np.zeros(0)
Pb_over_time=np.append(Pb_over_time,Pb_initial)
t_decay=np.zeros(0)
#genero i t_decay
for rn in range(Tl_initial):
    z = np.random.random()
    x = expon_icdf(z)
    t_decay=np.append(t_decay,x)
        
#print(t_decay)
t_decay=np.sort(t_decay)
l=t_decay.shape[0]
#conto decayed over time
#  1.0712e+01 1.0727e+01 1.0744e+01 1.0754e+01 1.0983e+01 1.0993e+01
#  1.1010e+01 1.1157e+01 1.1327e+01 1.1339e+01 1.1421e+01 1.1443e+01
#  1.1470e+01 1.1522e+01 1.1527e+01 1.1660e+01 1.1716e+01 1.1806e+01
#  1.1839e+01 1.1878e+01 1.1918e+01 1.1943e+01 1.1948e+01 1.2008e+01
#  1.2067e+01 1.2068e+01 1.2125e+01 1.2160e+01 1.2211e+01 1.2320e+01
#  1.2404e+01 1.2450e+01 1.2474e+01 1.2475e+01 1.2627e+01 1.2631e+01
#  1.2710e+01 1.2732e+01 1.2747e+01 1.2820e+01 1.2936e+01 1.2989e+01
#  1.3006e+01 1.3039e+01 1.3043e+01 1.3064e+01 1.3066e+01 1.3091e+01
#  1.3182e+01 1.3202e+01 1.3536e+01 1.3549e+01 1.3590e+01 1.3679e+01
#  1.3789e+01 1.4303e+01 1.4485e+01 1.4504e+01 1.4506e+01 1.5221e+01
#  1.5601e+01 1.5892e+01 1.6314e+01 1.7043e+01 1.7370e+01 1.7447e+01
#  1.7477e+01 1.7530e+01 1.7637e+01 1.7708e+01 1.7809e+01 1.8361e+01
#  1.8508e+01 1.8770e+01 1.9476e+01 1.9716e+01 1.9730e+01 2.1999e+01
#  2.2507e+01 2.3131e+01 2.6529e+01 2.7639e+01]
# [<matplotlib.lines.Line2D at 0x1e39d1fb3c8>,
#  <matplotlib.lines.Line2D at 0x1e39d1fb518>]

# %%
t_decay.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f654fd7b8975> in <module>()
# ----> 1 t_decay.shape
#
# NameError: name 't_decay' is not defined

# %% [markdown]
# 2\. **Rutherford Scattering**
#
# The scattering angle $\theta$ of $\alpha$ particles hitting a positively charged nucleus of a Gold atom ($Z=79$) follows the rule:
#
# $$
# \tan{\frac{1}{2} \theta} = \frac{Z e^2} {2\pi \epsilon_0 E b}
# $$
#
# where $E=7.7$ MeV and $b$ beam is the impact parameter. The beam is represented by a 2D gaussian distribution with $\sigma=a_0/100$ for both coordinates ($a_0$ being the Bohr radius). Assume 1 million $\alpha$ particles are shot on the gold atom.
#
# Computing the fraction of particles that "bounce back",i.e. those particle whose scattering angle is greater than $\pi/2$ (which set a condition on the impact parameter $b$)

# %%
import scipy.constants as sc
Z=79
E=7.7*10**6
N_alfa= 10**6
#print(sc.pi)
print(N_alfa//2)
# Out:
# 500000

# %%
#credo mi basti solo x (o solo y)
u1 = np.random.random(N_alfa//2)
u2 = np.random.random(N_alfa//2)
std= sc.physical_constants['Bohr radius'][0]/100
print(sc.e)
r_squared = -2*(std**2)*np.log(1-u1)
r = np.sqrt(r_squared)
theta = 2*np.pi*u2
x = r*np.cos(theta)
y = r*np.sin(theta)
b=np.concatenate((x,y))
b=np.abs(b)
print(b)
num=Z*sc.e**2
den=2*sc.pi*sc.epsilon_0*E
#print(num/den)
#print(den)
thresold=num/den
print(thresold)
#print(b)
bounce_back=b[b<np.abs(thresold)]
print(bounce_back.shape)
# Out:
# 1.6021766208e-19
# [4.8019e-13 1.1943e-13 6.2210e-13 ... 3.7247e-13 3.4354e-13 4.6301e-13]
# 4.7340032086384885e-33
# 4.7340032086384885e-33
# (0,)

# %% [markdown]
# 3\. **Monte Carlo integration: hit/miss vs mean value method**
#
# Consider the function
#
# $$f(x) =\sin^2{\frac{1}{x(2-x)}}$$
#
# * Compute the integral of $f(x)$ between 0 and 2 with the hit/miss method. Evaluate the error of your estimate
# * Repeat the integral with the mean value method. Evaluate the error and compare it with the previous one

# %%
import scipy.integrate as integrate
def f(x):
    return (np.sin(1/(x*(2-x))))**2

x=np.linspace(0.001,1.999,1000)
plt.plot(x,f(x),'r-')
I_true=integrate.quad(f,0,2)
print("true integra:",I_true)

# %%
# Monte Carlo integration HIT_MISS
N=10000
count=0

for i in range(N):
    x=2*np.random.random()
    y=np.random.random()
    if y<f(x): count+=1
I=2*count/N
print("estimated integral:",I)
#print(np.random.random())
print("error with hit miss:",np.abs(I_true[0]-I))

# %%
media= integral[0]/2
print("true mean:",media)

# %%
N=10000
values=np.zeros(0)

for i in range(N):
    x=2*np.random.random()
    values = np.append(values,f(x))
I_est=2*np.sum(values)/N
print("integral estimated with mean value:",I_est)
print("error using mean value:",np.abs(I_est-I_true[0])) #this performs better

# %% [markdown]
# 4\. **Monte Carlo integration in high dimension**
#
# * Start of by computing the area of a circle of unit radius, by integrating the function
#
# $$
# f(x,y)=
# \left\{
# \begin{array}{ll}
#       1 & x^2+y^2\le 1 \\
#       0 & {\rm elsewhere}
# \end{array}
# \right.
# $$
#
# * Generalize the result for a 10D sphere

# %%
def fun(x):
    n_dim = x.size
    values=np.zeros(0)
    for i in range(n_dim):
        values=np.append(values,x[i]**2)
    f = np.abs(np.sum(values))
    #return f
    if f<=1:
        return 1
    else: 
        return 0

# %%
fun(np.array([1,0,0]))

# %%
N=10000
values_fun=np.zeros(0)
n_dim=2
a=0
b=1
for i in range(N):
    values=np.zeros(0)
    for i in range(n_dim):
        A=np.random.randint(a,b)
        x=A*np.random.random()
        values=np.append(values,x)
    values_fun=np.append(values_fun,fun(values))

I_est=(b-a)*np.sum(values_fun)/N
#in general (a2-a1)(b2-b1)(c2-c1)
print("estimated integral:", I_est)

# %% [markdown]
# 5\. **Monte Carlo integration with importance sampling**
#
# Calculate the value of the integral:
#
# $$
# I=\int_0^1 \frac{x^{-1/2}}{e^x+1} dx
# $$
#
# using the importance sampling method with $w(x)=1/\sqrt{x}$. You should get a result about 0.84

# %%
def fun2(x):
    return x**(-0.5)/(np.exp(x)+1)

def weight_pdf(x):
    """PDF of exponential distribution."""
    return x**(-0.5)

def weight_cdf(x):
    """CDF of exponetial distribution."""
    return 2*x**0.5

def weight_icdf(p):
    """Inverse CDF of exponential distribution - i.e. quantile function."""
    return (p/2)**2

# %%
N=10000
values_fun=np.zeros(0)
n_dim=2
a=0
b=1
for i in range(N):
    z=np.random.random()
    x= weight_icdf(z)
    values_fun=np.append(values_fun,fun2(x)/weight_pdf(x))
    

I_est=np.sum(values_fun)/N*2
print(values_fun, np.sum(values_fun))
#in general 
print("estimated integral:", I_est)
# Out:
# [0.4999 0.499  0.4991 ... 0.4995 0.4967 0.4856] 4788.445174212522
# estimated integral: 0.9576890348425044
