# %% [markdown]
# ## Pandas analysis
#
# In the following a series of exercises is proposed on a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGA's. Each measurement (i.e. each raw) consists of the address of the TDC providing the signal, 'FPGA' and 'TDC_Channel, and the timing information itself, 'ORBIT_CNT', 'BX_COUNTER' and 'TDC_MEAS'. Each TDC count correspond 25/30 ns, whereas the BX_COUNTER feauters gets updated every 25 ns and the ORBIT_CNT every 'x' BX_COUNTER. You can see these way of storing the time as similar to hours, minutes and seconds.
#
# 1\. Create a Pandas DataFrame by read N raws of the 'data_000637.txt' dataset. Choose N to be smaller than or equal to the maximum number of raws and larger that 10k.
#
# 2\. Find out the value of 'x'
#
# 3\. Find out how much the data taking lasted. You can either make an estimate on the baseis of the fraction of the measurements (raws) you read, or perform this check precisely by reading out the whole dataset
#
# 4\. Create a new column with the actual time in ns (as a combination of the other three columns with timing information)
#
# 5\. Replace the values (all 1) of the HEAD column randomly with 0 or 1
#
# 6\. Create a new DataFrame with only the raws with HEAD=1
#
# 7\. Make two occupancy plots (one per FPGA), i.e. plot the number of counts per TDC channel
#
# 8\. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)
#
# 9\. Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

# %%
import pandas as pd
import numpy as np
import time

pd.set_option("display.precision", 15)
filename = '/Users/caterinaboscolomeneguolo/data/data_000637.txt'
N=100000

start = time.time()
data = np.loadtxt(filename,delimiter=',',skiprows=1,dtype='float64')
indexes = np.arange(N)
df = pd.DataFrame(data[:N],index=indexes,columns=['HEAD','FPGA','TDC_CHANNEL','ORBIT_CNT','BX_COUNTER','TDC_MEAS'],dtype='float64')
end = time.time()

df.head()
# Out:
#    HEAD  FPGA  TDC_CHANNEL     ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0   1.0   0.0        123.0  3869200167.0      2374.0      26.0
# 1   1.0   0.0        124.0  3869200167.0      2374.0      27.0
# 2   1.0   0.0         63.0  3869200167.0      2553.0      28.0
# 3   1.0   0.0         64.0  3869200167.0      2558.0      19.0
# 4   1.0   0.0         64.0  3869200167.0      2760.0      25.0

# %%
# some ordering...
dfg = df.sort_values(by=['TDC_CHANNEL','ORBIT_CNT','BX_COUNTER'])
dfg.head(10)
# Out:
#      HEAD  FPGA  TDC_CHANNEL     ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 43    1.0   1.0          1.0  3869200168.0         7.0      18.0
# 45    1.0   1.0          1.0  3869200168.0        13.0      18.0
# 65    1.0   1.0          1.0  3869200168.0       281.0      24.0
# 76    1.0   1.0          1.0  3869200168.0      1328.0       4.0
# 78    1.0   1.0          1.0  3869200168.0      1454.0      12.0
# 130   1.0   1.0          1.0  3869200169.0       131.0       1.0
# 157   1.0   1.0          1.0  3869200169.0       264.0       5.0
# 169   1.0   1.0          1.0  3869200169.0       668.0      11.0
# 206   1.0   1.0          1.0  3869200169.0      1330.0      18.0
# 233   1.0   1.0          1.0  3869200169.0      1989.0       3.0

# %%
# 2. Find out the value of 'x'

dfgroup=dfg.groupby(['HEAD','FPGA','TDC_CHANNEL','ORBIT_CNT']).max()
x = dfgroup['BX_COUNTER'].max()+1
print('x =', x)
# Out:
# x = 3564.0

# %%
# 3. Find out how much the data taking lasted. 
print (end - start)
# Out:
# 14.952397108078003

# %%
# 4. Create a new column with the actual time in ns (as a combination of the other three columns with timing information)
df['ACT_TIME']=pd.Series( (df['BX_COUNTER']+df['ORBIT_CNT']*x)*25, index=df.index)
df.head()
# Out:
#    HEAD  FPGA  TDC_CHANNEL     ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0     1   0.0        123.0  3869200167.0      2374.0      26.0
# 1     1   0.0        124.0  3869200167.0      2374.0      27.0
# 2     1   0.0         63.0  3869200167.0      2553.0      28.0
# 3     1   0.0         64.0  3869200167.0      2558.0      19.0
# 4     0   0.0         64.0  3869200167.0      2760.0      25.0
#
#             ACT_TIME
# 0  344745734939050.0
# 1  344745734939050.0
# 2  344745734943525.0
# 3  344745734943650.0
# 4  344745734948700.0

# %%
# 5. Replace the values (all 1) of the HEAD column randomly with 0 or 1
df['HEAD']=pd.Series(np.random.randint(0,2,(len(df.index))))
df.head()
# Out:
#    HEAD  FPGA  TDC_CHANNEL     ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0     1   0.0        123.0  3869200167.0      2374.0      26.0
# 1     1   0.0        124.0  3869200167.0      2374.0      27.0
# 2     1   0.0         63.0  3869200167.0      2553.0      28.0
# 3     1   0.0         64.0  3869200167.0      2558.0      19.0
# 4     0   0.0         64.0  3869200167.0      2760.0      25.0
#
#             ACT_TIME
# 0  344745734939050.0
# 1  344745734939050.0
# 2  344745734943525.0
# 3  344745734943650.0
# 4  344745734948700.0

# %%
# 6. Create a new DataFrame with only the raws with HEAD=1
df_new = df[df['HEAD']==1]
#df_new

# %%
# 7. Make two occupancy plots (one per FPGA), i.e. plot the number of counts per TDC channel
df_00 = df[df['FPGA']==0.0]
df_00_count = df_00.groupby(['FPGA','TDC_CHANNEL']).count()

channel00 = df_00_count.index.get_level_values('TDC_CHANNEL')
counts00 = df_00_count.iloc[:,1]

df_01=df[df['FPGA']==1.0]
df_01_count = df_01.groupby(['FPGA','TDC_CHANNEL']).count()

channel01 = df_01_count.index.get_level_values('TDC_CHANNEL')
counts01 = df_01_count.iloc[:,1]

# %%
import matplotlib.pyplot as plt

fig, (ax0,ax1) = plt.subplots(nrows=2, ncols=1, figsize=(8, 8))

ax0.plot(channel00,counts00,label='FPGA0')
ax1.plot(channel01,counts01,label='FPGA1')
ax0.legend(loc=9)
ax1.legend(loc=9)

# %%
# 8. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)
df_00_count.sort_values('TDC_MEAS')
print("top noisy channels for FPGA0: ",
      df_00_count.sort_values('TDC_MEAS').index.get_level_values('TDC_CHANNEL').tolist()[-3:])
print("top noisy channels for FPGA1: ",
      df_01_count.sort_values('TDC_MEAS').index.get_level_values('TDC_CHANNEL').tolist()[-3:])
# Out:
# top noisy channels for FPGA0:  [63.0, 64.0, 139.0]
# top noisy channels for FPGA1:  [1.0, 2.0, 139.0]

# %%
# 9. Count the number of unique orbits. 
# Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139
