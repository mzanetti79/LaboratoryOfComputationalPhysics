# %% [markdown]
# 1\. Write a function that converts number representation (bin<->dec<->hex)

# %%
# Different implementation of converter function in order 
# to practise with shift and bitwise operator


# Converter from decimal to binary
def dec2bin(n, N=64):
    result = '0b'
    for i in range(N,0,-1):
        var = n>>(i-1)
        if (var & 1) :
            result = result + str( int(var & 1) )
        else:
            result = result + str( 0 )
    return result


# Converter from binary to decimal
def bin2dec(n, N=64):
    result = 0
    for i in range(N-1,-1,-1):
        var = int( n * (10**(-i)) )
        if var:
            result = result + int(str(var)[len(str(n))-1-i]) * ( 2**(i) )
    return result


# Converter from decimal to hexadecimal
def dec2hex(n):
    result = ''
    dic = {
            "10":'A',
            "11":'B',
            "12":'C',
            "13":'D',
            "14":'E',
            "15":'F'
          }  
    for i in range( 1,len(str(n))+1):
        var = n >> ( 4*(i) )
        reminder = (n//(2**(4*(i-1)))) - var *(16)
        if (reminder <=9) :
            result = str( reminder ) + result 
        else:
            result = dic[str(reminder)] + result 
    return '0x' + result


# Converter from hexadecimal to decimal
# Hexadecimal input number must be passed as string
def hex2dec(n):
    result = 0
    dic = {
            "A":'10',
            "B":'11',
            "C":'12',
            "D":'13',
            "E":'14',
            "F":'15',
            "x":'0'
          }  
    n_str = str(n)
    j = len(n_str)-1
    for digit in n_str:
        try:
            result = result + int(digit) * (16**j)
        except:
            result = result + int(dic[digit]) * (16**j)
        j = j-1
    return result


# Converter from binary to hexadecimal
def bin2hex(n):
    return dec2hex( bin2dec(n) )


# Converter from hexadecimal to binary
def hex2bin(n):
    return dec2bin( hex2dec(n) )

# %%
# General converter (bin<->dec<->hex)
def numb_conv( number, conv_format):
    conv_format = str(conv_format)
    dic = {
            'dec2bin':dec2bin,
            'bin2dec':bin2dec,
            'dec2hex':dec2hex,
            'hex2dec':hex2dec,
            'bin2hex':bin2hex,
            'hex2bin':hex2bin
          }  
    try:
        result = dic[conv_format](number)
        return result
    except:
        print('Error in ' + str(conv_format)+ ': You maybe not pass a string as input or the string you pass is not a valid conversion format')
        return

# %%
# Tetsting
result1 = numb_conv(4,'dec2bin')
print("dec2bin:", result1)

result2 = numb_conv(10101000,'bin2dec')
print("\nbin2dec:", result2)

result3 = numb_conv(4, 'dec2hex')
print("\ndec2hex:", result3)

result4 = numb_conv('0xF', 'hex2dec')
print("\nhex2dec:", result4)

result5 = numb_conv(100, 'bin2hex')
print("\nbin2hex:", result5)

result6 = numb_conv('0xF', 'hex2bin')
print("\nhex2bin:", result6)

# %% [markdown]
# 2\. Write a function that converts a 32 bit word into a single precision floating point (i.e. interprets the various bits as sign, mantissa and exponent)

# %%
# Input number n must be passed as string
def bin32ToFloat(n):
    prefix = n[0:2]
    
    if prefix == '0b':
        n = n[2::]
    
    if len( n ) == 32:
        sign = int( n[0] )
        exp = int( n[1:9],2 )
        mantissa = 1 + sum([ int(b) * 2**(-i-1) for (i,b) in enumerate(n[9::])])
        print('sign:', sign)
        print('exp:', exp)
        print('mantissa:', mantissa)
        return (-1)**(sign) * 2**(exp-127) * mantissa
    
    else:
        print("Input number is not at 32 bit precision")
        return
        
        
# Testing
num = '0b01000000010010010000111111011011'
bin32ToFloat(num)

# %% [markdown]
# 3\. Write a program to determine the underflow and overflow limits (within a factor of 2) for python on your computer.
#
# **Tips**: define two variables inizialized to 1 and halve/double them enough time to exceed the under/over-flow limits

# %%
# Underflow
under = 1
while under != 0:
    min_ = under
    under = under/2
print('Underflow limit:', min_)


# Overflow
over = 1
while over/over == 1:
    max_ = over
    over = over * 2.
print('Overflow limit:', max_)

# %% [markdown]
# 4\. Write a program to determine the machine precision
#
# **Tips**: define a new variable by adding a smaller and smaller value (proceeding similarly to prob. 2) to an original variable and check the point where the two are the same

# %%
start = 1.

step = 1.
end = 0.
while start != end:
    result = step
    step = step/2
    end = start + step
    
print(result)

# %% [markdown]
# 5\. Write a function that takes in input three parameters $a$, $b$ and $c$ and prints out the two solutions to the quadratic equation $ax^2+bx+c=0$ using the standard formula:
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# (a) use the program to compute the solution for $a=0.001$, $b=1000$ and $c=0.001$
#
# (b) re-express the standard solution formula by multiplying top and bottom by $-b\mp\sqrt{b^2-4ac}$ and again find the solution for $a=0.001$, $b=1000$ and $c=0.001$. How does it compare with what previously obtained? Why?
#
# (c) write a function that compute the roots of a quadratic equation accurately in all cases

# %%
import cmath

def quad_solver1( a, b, c):
    x1 = ( -b + cmath.sqrt( b**2 - 4*a*c ) ) / ( 2*a ) 
    x2 = ( -b - cmath.sqrt( b**2 - 4*a*c ) ) / ( 2*a ) 
    return x1, x2

def quad_solver2( a, b, c):
    x1 = ( 2*c ) / ( ( -b - cmath.sqrt( b**2 - 4*a*c ) ) )
    x2 = ( 2*c ) / ( ( -b + cmath.sqrt( b**2 - 4*a*c ) ) )
    return x1, x2

def quad_solver3( a, b, c):
    x1 = quad_solver2( a, b, c)[0]
    x2 = quad_solver1( a, b, c)[1]
    return x1, x2

# (a.)
a = 0.001
b = 1000
c = 0.001
x1, x2 = quad_solver1( a, b, c)
print('----- QUADRATIC SOLVER 1 -----')
print('x1:', x1)
print('x2:', x2)

# (b.)
a = 0.001
b = 1000
c = 0.001
x1, x2 = quad_solver2( a, b, c)
print('\n----- QUADRATIC SOLVER 2 -----')
print('x1:', x1)
print('x2:', x2)

# (c.)
a = 0.001
b = 1000
c = 0.001
x1, x2 = quad_solver3( a, b, c)
print('\n----- QUADRATIC SOLVER 3 -----')
print('x1:', x1)
print('x2:', x2)

# %% [markdown]
# 6\. Write a program that implements the function $f(x)=x(x−1)$
#
# (a) Calculate the derivative of the function at the point $x = 1$ using the derivative definition:
#
# $$
# \frac{{\rm d}f}{{\rm d}x} = \lim_{\delta\to0} \frac{f(x+\delta)-f(x)}{\delta}
# $$
#
# with $\delta = 10^{−2}$. Calculate the true value of the same derivative analytically and compare with the answer your program gives. The two will not agree perfectly. Why not?
#
# (b) Repeat the calculation for $\delta = 10^{−4}, 10^{−6}, 10^{−8}, 10^{−10}, 10^{−12}$ and $10^{−14}$. How does the accuracy scales with $\delta$?

# %%
import matplotlib.pyplot as plt

def f(x):
    return x*(x-1)

def derivative_1d( f, x, delta ):
    return ( f(x+delta) - f(x) ) / ( delta )

true_result = 1
print( 'Hand-computed result:\n', true_result )

# (a.)
x = 1
delta = 10**(-2)
result = derivative_1d( f, x, delta )
print( '\nResult computed by derivative_1d:\n', result )

#(b.)
deltas = [ 10**(-i) for i in range(4,15,2) ]
results = [ derivative_1d( f, x, d ) for d in deltas ]
print( '\nResult computed by derivative_1d varying delta:\n', results )

plt.plot( deltas, results, 'ko', label='derivative' )
plt.plot( deltas, [1 for i in range(4,15,2)], 'b-', label='true result' )
plt.xscale('log')
plt.legend()
plt.xlabel('delta')
plt.ylabel('derivative of x(x-1)')

# %% [markdown]
# The precision increases untill $\delta$ becomes equal to $10^{-8}$. After ( $\delta < 10^{-8}$ ) the precision decreases.

# %% [markdown]
# 7\. Consider the integral of the semicircle of radius 1:
# $$
# I=\int_{-1}^{1} \sqrt(1-x^2) {\rm d}x
# $$
# which it's known to be $I=\frac{\pi}{2}=1.57079632679...$.
# Alternatively we can use the Riemann definition of the integral:
# $$
# I=\lim_{N\to\infty} \sum_{k=1}^{N} h y_k
# $$
#
# with $h=2/N$ the width of each of the $N$ slices the domain is divided into and where
# $y_k$ is the value of the function at the $k-$th slice.
#
# (a) Write a programe to compute the integral with $N=100$. How does the result compares to the true value?
#
# (b) How much can $N$ be increased if the computation needs to be run in less than a second? What is the gain in running it for 1 minute?

# %%
import math
import time

def y(x):
    return math.sqrt(1-x**2)

# (a.) Implementation using Riemann definition
def integral( start, end, f, N ):
    h = end - start
    start = start*N
    end = end*N
    I = sum( [ (h/N)*y(x/N) for x in range(start,end,h) ] )
    return I

# (b.) Increasing N..
for n in range(100,10**10,10**4):
    t0 = time.process_time()
    I = integral(-1,1, y, n)
    t1 = time.process_time()
    print( '\n------- ' + str(n) + ' ITERATIONS -------')
    print('Time:' + str(t1-t0) + ' s')
    print('Result:', I)
    if t1-t0 > 1.:
        break

print('\nIn order to keep the algo performance lower than a second, the maximum value of N is:', n-10**4)
print('Error is:', abs( integral(-1,1, y, n-10**4) - math.pi/2 ))

# %%
# and waiting for about a minute..
it = 1500100*60
t0 = time.process_time()
i = integral(-1,1, y, it)
t1 = time.process_time()
print('\n------- And waiting for a minute -------')
print('Time: ' + str(t1-t0) + ' s' )
print('Result:', i)
print('Error is:', abs( i - math.pi/2 ) )
