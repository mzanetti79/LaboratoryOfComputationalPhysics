# %% [markdown]
# 1\. Write a function that converts number representation (bin<->dec<->hex)

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __ceil__(...)
#  |      Ceiling of an Integral returns itself.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(...)
#  |      Flooring an Integral returns itself.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Default object formatter.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __index__(self, /)
#  |      Return self converted to an integer, if self is suitable for use as an index into a list.
#  |
#  |  __int__(self, /)
#  |      int(self)
#  |
#  |  __invert__(self, /)
#  |      ~self
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lshift__(self, value, /)
#  |      Return self<<value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mod__(self, value, /)
#  |      Return self%value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __neg__(self, /)
#  |      -self
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __pos__(self, /)
#  |      +self
#  |
#  |  __pow__(self, value, mod=None, /)
#  |      Return pow(self, value, mod).
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __rdivmod__(self, value, /)
#  |      Return divmod(value, self).
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rfloordiv__(self, value, /)
#  |      Return value//self.
#  |
#  |  __rlshift__(self, value, /)
#  |      Return value<<self.
#  |
#  |  __rmod__(self, value, /)
#  |      Return value%self.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __round__(...)
#  |      Rounding an Integral returns itself.
#  |      Rounding with an ndigits argument also returns an integer.
#  |
#  |  __rpow__(self, value, mod=None, /)
#  |      Return pow(value, self, mod).
#  |
#  |  __rrshift__(self, value, /)
#  |      Return value>>self.
#  |
#  |  __rshift__(self, value, /)
#  |      Return self>>value.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rtruediv__(self, value, /)
#  |      Return value/self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sizeof__(self, /)
#  |      Returns size in memory, in bytes.
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __truediv__(self, value, /)
#  |      Return self/value.
#  |
#  |  __trunc__(...)
#  |      Truncating an Integral returns itself.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  bit_length(self, /)
#  |      Number of bits necessary to represent self in binary.
#  |
#  |      >>> bin(37)
#  |      '0b100101'
#  |      >>> (37).bit_length()
#  |      6
#  |
#  |  conjugate(...)
#  |      Returns self, the complex conjugate of any int.
#  |
#  |  to_bytes(self, /, length, byteorder, *, signed=False)
#  |      Return an array of bytes representing an integer.
#  |
#  |      length
#  |        Length of bytes object to use.  An OverflowError is raised if the
#  |        integer is not representable with the given number of bytes.
#  |      byteorder
#  |        The byte order used to represent the integer.  If byteorder is 'big',
#  |        the most significant byte is at the beginning of the byte array.  If
#  |        byteorder is 'little', the most significant byte is at the end of the
#  |        byte array.  To request the native byte order of the host system, use
#  |        `sys.byteorder' as the byte order value.
#  |      signed
#  |        Determines whether two's complement is used to represent the integer.
#  |        If signed is False and a negative integer is given, an OverflowError
#  |        is raised.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  from_bytes(bytes, byteorder, *, signed=False) from builtins.type
#  |      Return the integer represented by the given array of bytes.
#  |
#  |      bytes
#  |        Holds the array of bytes to convert.  The argument must either
#  |        support the buffer protocol or be an iterable object producing bytes.
#  |        Bytes and bytearray are examples of built-in objects that support the
#  |        buffer protocol.
#  |      byteorder
#  |        The byte order used to represent the integer.  If byteorder is 'big',
#  |        the most significant byte is at the beginning of the byte array.  If
#  |        byteorder is 'little', the most significant byte is at the end of the
#  |        byte array.  To request the native byte order of the host system, use
#  |        `sys.byteorder' as the byte order value.
#  |      signed
#  |        Indicates whether two's complement is used to represent the integer.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  denominator
#  |      the denominator of a rational number in lowest terms
#  |
#  |  imag
#  |      the imaginary part of a complex number
#  |
#  |  numerator
#  |      the numerator of a rational number in lowest terms
#  |
#  |  real
#  |      the real part of a complex number

# %%
def converter(x, starting_base, arriving_base):
    if starting_base == 'bin':
        if arriving_base == 'dec':
            return int(x, base = 2)
        else:
            print('Case not handled.')
    elif starting_base == 'hex':
        if arriving_base == 'dec':
            return int(x, base = 16)
        else:
            print('Case not handled.')
    elif starting_base == 'dec':
        if arriving_base == 'bin':
            return bin(x)
        elif arriving_base == 'hex':
            return hex(x)
        else:
            print('Case not handled.')
    else:
        print('Case not handled.')

# %%
print(converter(10, 'dec', 'bin'))
print(converter(10, 'dec', 'hex'))
print(converter('0111', 'bin', 'hex'))
print(converter('0111', 'bin', 'dec'))
print(converter('0ae2', 'hex', 'dec'))
# Out:
# 0b1010
# 0xa
# Case not handled.
# None
# 7
# 2786

# %% [markdown]
# 2\. Write a function that converts a 32 bit word into a single precision floating point (i.e. interprets the various bits as sign, mantissa and exponent)

# %%
sign = '1' # -1
exp = '10000000' # 128 (equal to the bias + 1)
frac_mantissa = '1'
for i in range(22):
    frac_mantissa += '0' # mantissa = (1.1000..0)2 -> 1.5 in decimal base
test_string = sign+exp+frac_mantissa
print('Test string: ', test_string, '\n')
print(len(test_string))

def single_precision_interpreter(string):
    if len(string) == 32:
        s = (-1)**int(string[0])
        e = -127
        for i in range(1,9):
            e = e + int(string[i])*2**(8-i)
        m = 1
        for i in range(1,24):
            m = m + int(string[i+8])/2**i
        return s*pow(m,e)
    else:
        print('Input string doesn\'t have 32 bits')

print(single_precision_interpreter(test_string))
# Out:
# Test string:  11000000010000000000000000000000
#
# 32
# -1.5

# %% [markdown]
# 3\. Write a program to determine the underflow and overflow limits (within a factor of 2) for python on your computer.
#
# **Tips**: define two variables inizialized to 1 and halve/double them enough time to exceed the under/over-flow limits

# %%
overflow = 1.

i = 0
# this works because python can exceed the 64 bits for integers, but not for floats
while(overflow == 2**i and i < 10000):
    i = i+1
    overflow *= 2
print('Max exponent of 2**i before overflow: i = ', i, '\n')
print('Corresponding number: ', 2**i)
# Out:
# Max exponent of 2**i before overflow: i =  1024
#
# Corresponding number:  

# %%
underflow = 1.
j = 0
T = True
while(T and j < 100000):
    j = j+1
    underflow /= 2
    print('underflow at step {} : {}'.format(j, underflow) )
    try:
        T = underflow*2**(j)
    except:
        print('Overflow error')
        T = False
    
print('Max exponent of 2**(-i) before underflow: i = ', j-1, '\n')
print('Corresponding number: ', 2**(-j+1))
# Out:
# underflow at step 1 : 0.5
# underflow at step 2 : 0.25
# underflow at step 3 : 0.125
# underflow at step 4 : 0.0625
# underflow at step 5 : 0.03125
# underflow at step 6 : 0.015625
# underflow at step 7 : 0.0078125
# underflow at step 8 : 0.00390625
# underflow at step 9 : 0.001953125
# underflow at step 10 : 0.0009765625
# underflow at step 11 : 0.00048828125
# underflow at step 12 : 0.000244140625
# underflow at step 13 : 0.0001220703125
# underflow at step 14 : 6.103515625e-05
# underflow at step 15 : 3.0517578125e-05
# underflow at step 16 : 1.52587890625e-05
# underflow at step 17 : 7.62939453125e-06
# underflow at step 18 : 3.814697265625e-06
# underflow at step 19 : 1.9073486328125e-06
# underflow at step 20 : 9.5367431640625e-07
# underflow at step 21 : 4.76837158203125e-07
# underflow at step 22 : 2.384185791015625e-07
# underflow at step 23 : 1.1920928955078125e-07
# underflow at step 24 : 5.960464477539063e-08
# underflow at step 25 : 2.9802322387695312e-08
# underflow at step 26 : 1.4901161193847656e-08
# underflow at step 27 : 7.450580596923828e-09
# underflow at step 28 : 3.725290298461914e-09
# underflow at step 29 : 1.862645149230957e-09
# underflow at step 30 : 9.313225746154785e-10
# underflow at step 31 : 4.656612873077393e-10
# underflow at step 32 : 2.3283064365386963e-10
# underflow at step 33 : 1.1641532182693481e-10
# underflow at step 34 : 5.820766091346741e-11
# underflow at step 35 : 2.9103830456733704e-11
# underflow at step 36 : 1.4551915228366852e-11
# underflow at step 37 : 7.275957614183426e-12
# underflow at step 38 : 3.637978807091713e-12
# underflow at step 39 : 1.8189894035458565e-12
# underflow at step 40 : 9.094947017729282e-13
# underflow at step 41 : 4.547473508864641e-13
# underflow at step 42 : 2.2737367544323206e-13
# underflow at step 43 : 1.1368683772161603e-13
# underflow at step 44 : 5.684341886080802e-14
# underflow at step 45 : 2.842170943040401e-14
# underflow at step 46 : 1.4210854715202004e-14
# underflow at step 47 : 7.105427357601002e-15
# underflow at step 48 : 3.552713678800501e-15
# underflow at step 49 : 1.7763568394002505e-15
# underflow at step 50 : 8.881784197001252e-16
# underflow at step 51 : 4.440892098500626e-16
# underflow at step 52 : 2.220446049250313e-16
# underflow at step 53 : 1.1102230246251565e-16
# underflow at step 54 : 5.551115123125783e-17
# underflow at step 55 : 2.7755575615628914e-17
# underflow at step 56 : 1.3877787807814457e-17
# underflow at step 57 : 6.938893903907228e-18
# underflow at step 58 : 3.469446951953614e-18
# underflow at step 59 : 1.734723475976807e-18
# underflow at step 60 : 8.673617379884035e-19
# underflow at step 61 : 4.336808689942018e-19
# underflow at step 62 : 2.168404344971009e-19
# underflow at step 63 : 1.0842021724855044e-19
# underflow at step 64 : 5.421010862427522e-20
# underflow at step 65 : 2.710505431213761e-20
# underflow at step 66 : 1.3552527156068805e-20
# underflow at step 67 : 6.776263578034403e-21
# underflow at step 68 : 3.3881317890172014e-21
# underflow at step 69 : 1.6940658945086007e-21
# underflow at step 70 : 8.470329472543003e-22
# underflow at step 71 : 4.235164736271502e-22
# underflow at step 72 : 2.117582368135751e-22
# underflow at step 73 : 1.0587911840678754e-22
# underflow at step 74 : 5.293955920339377e-23
# underflow at step 75 : 2.6469779601696886e-23
# underflow at step 76 : 1.3234889800848443e-23
# underflow at step 77 : 6.617444900424222e-24
# underflow at step 78 : 3.308722450212111e-24
# underflow at step 79 : 1.6543612251060553e-24
# underflow at step 80 : 8.271806125530277e-25
# underflow at step 81 : 4.1359030627651384e-25
# underflow at step 82 : 2.0679515313825692e-25
# underflow at step 83 : 1.0339757656912846e-25
# underflow at step 84 : 5.169878828456423e-26
# underflow at step 85 : 2.5849394142282115e-26
# underflow at step 86 : 1.2924697071141057e-26
# underflow at step 87 : 6.462348535570529e-27
# underflow at step 88 : 3.2311742677852644e-27
# underflow at step 89 : 1.6155871338926322e-27
# underflow at step 90 : 8.077935669463161e-28
# underflow at step 91 : 4.0389678347315804e-28
# underflow at step 92 : 2.0194839173657902e-28
# underflow at step 93 : 1.0097419586828951e-28
# underflow at step 94 : 5.048709793414476e-29
# underflow at step 95 : 2.524354896707238e-29
# underflow at step 96 : 1.262177448353619e-29
# underflow at step 97 : 6.310887241768095e-30
# underflow at step 98 : 3.1554436208840472e-30
# underflow at step 99 : 1.5777218104420236e-30
# underflow at step 100 : 7.888609052210118e-31
# underflow at step 101 : 3.944304526105059e-31
# underflow at step 102 : 1.9721522630525295e-31
# underflow at step 103 : 9.860761315262648e-32
# underflow at step 104 : 4.930380657631324e-32
# underflow at step 105 : 2.465190328815662e-32
# underflow at step 106 : 1.232595164407831e-32
# underflow at step 107 : 6.162975822039155e-33
# underflow at step 108 : 3.0814879110195774e-33
# underflow at step 109 : 1.5407439555097887e-33
# underflow at step 110 : 7.703719777548943e-34
# underflow at step 111 : 3.851859888774472e-34
# underflow at step 112 : 1.925929944387236e-34
# underflow at step 113 : 9.62964972193618e-35
# underflow at step 114 : 4.81482486096809e-35
# underflow at step 115 : 2.407412430484045e-35
# underflow at step 116 : 1.2037062152420224e-35
# underflow at step 117 : 6.018531076210112e-36
# underflow at step 118 : 3.009265538105056e-36
# underflow at step 119 : 1.504632769052528e-36
# underflow at step 120 : 7.52316384526264e-37
# underflow at step 121 : 3.76158192263132e-37
# underflow at step 122 : 1.88079096131566e-37
# underflow at step 123 : 9.4039548065783e-38
# underflow at step 124 : 4.70197740328915e-38
# underflow at step 125 : 2.350988701644575e-38
# underflow at step 126 : 1.1754943508222875e-38
# underflow at step 127 : 5.877471754111438e-39
# underflow at step 128 : 2.938735877055719e-39
# underflow at step 129 : 1.4693679385278594e-39
# underflow at step 130 : 7.346839692639297e-40
# underflow at step 131 : 3.6734198463196485e-40
# underflow at step 132 : 1.8367099231598242e-40
# underflow at step 133 : 9.183549615799121e-41
# underflow at step 134 : 4.591774807899561e-41
# underflow at step 135 : 2.2958874039497803e-41
# underflow at step 136 : 1.1479437019748901e-41
# underflow at step 137 : 5.739718509874451e-42
# underflow at step 138 : 2.8698592549372254e-42
# underflow at step 139 : 1.4349296274686127e-42
# underflow at step 140 : 7.174648137343064e-43
# underflow at step 141 : 3.587324068671532e-43
# underflow at step 142 : 1.793662034335766e-43
# underflow at step 143 : 8.96831017167883e-44
# underflow at step 144 : 4.484155085839415e-44
# underflow at step 145 : 2.2420775429197073e-44
# underflow at step 146 : 1.1210387714598537e-44
# underflow at step 147 : 5.605193857299268e-45
# underflow at step 148 : 2.802596928649634e-45
# underflow at step 149 : 1.401298464324817e-45
# underflow at step 150 : 7.006492321624085e-46
# underflow at step 151 : 3.503246160812043e-46
# underflow at step 152 : 1.7516230804060213e-46
# underflow at step 153 : 8.758115402030107e-47
# underflow at step 154 : 4.3790577010150533e-47
# underflow at step 155 : 2.1895288505075267e-47
# underflow at step 156 : 1.0947644252537633e-47
# underflow at step 157 : 5.473822126268817e-48
# underflow at step 158 : 2.7369110631344083e-48
# underflow at step 159 : 1.3684555315672042e-48
# underflow at step 160 : 6.842277657836021e-49
# underflow at step 161 : 3.4211388289180104e-49
# underflow at step 162 : 1.7105694144590052e-49
# underflow at step 163 : 8.552847072295026e-50
# underflow at step 164 : 4.276423536147513e-50
# underflow at step 165 : 2.1382117680737565e-50
# underflow at step 166 : 1.0691058840368783e-50
# underflow at step 167 : 5.345529420184391e-51
# underflow at step 168 : 2.6727647100921956e-51
# underflow at step 169 : 1.3363823550460978e-51
# underflow at step 170 : 6.681911775230489e-52
# underflow at step 171 : 3.3409558876152446e-52
# underflow at step 172 : 1.6704779438076223e-52
# underflow at step 173 : 8.352389719038111e-53
# underflow at step 174 : 4.176194859519056e-53
# underflow at step 175 : 2.088097429759528e-53
# underflow at step 176 : 1.044048714879764e-53
# underflow at step 177 : 5.22024357439882e-54
# underflow at step 178 : 2.61012178719941e-54
# underflow at step 179 : 1.305060893599705e-54
# underflow at step 180 : 6.525304467998525e-55
# underflow at step 181 : 3.2626522339992623e-55
# underflow at step 182 : 1.6313261169996311e-55
# underflow at step 183 : 8.156630584998156e-56
# underflow at step 184 : 4.078315292499078e-56
# underflow at step 185 : 2.039157646249539e-56
# underflow at step 186 : 1.0195788231247695e-56
# underflow at step 187 : 5.0978941156238473e-57
# underflow at step 188 : 2.5489470578119236e-57
# underflow at step 189 : 1.2744735289059618e-57
# underflow at step 190 : 6.372367644529809e-58
# underflow at step 191 : 3.1861838222649046e-58
# underflow at step 192 : 1.5930919111324523e-58
# underflow at step 193 : 7.965459555662261e-59
# underflow at step 194 : 3.982729777831131e-59
# underflow at step 195 : 1.9913648889155653e-59
# underflow at step 196 : 9.956824444577827e-60
# underflow at step 197 : 4.9784122222889134e-60
# underflow at step 198 : 2.4892061111444567e-60
# underflow at step 199 : 1.2446030555722283e-60
# underflow at step 200 : 6.223015277861142e-61
# underflow at step 201 : 3.111507638930571e-61
# underflow at step 202 : 1.5557538194652854e-61
# underflow at step 203 : 7.778769097326427e-62
# underflow at step 204 : 3.8893845486632136e-62
# underflow at step 205 : 1.9446922743316068e-62
# underflow at step 206 : 9.723461371658034e-63
# underflow at step 207 : 4.861730685829017e-63
# underflow at step 208 : 2.4308653429145085e-63
# underflow at step 209 : 1.2154326714572542e-63
# underflow at step 210 : 6.077163357286271e-64
# underflow at step 211 : 3.0385816786431356e-64
# underflow at step 212 : 1.5192908393215678e-64
# underflow at step 213 : 7.596454196607839e-65
# underflow at step 214 : 3.7982270983039195e-65
# underflow at step 215 : 1.8991135491519597e-65
# underflow at step 216 : 9.495567745759799e-66
# underflow at step 217 : 4.7477838728798994e-66
# underflow at step 218 : 2.3738919364399497e-66
# underflow at step 219 : 1.1869459682199748e-66
# underflow at step 220 : 5.934729841099874e-67
# underflow at step 221 : 2.967364920549937e-67
# underflow at step 222 : 1.4836824602749686e-67
# underflow at step 223 : 7.418412301374843e-68
# underflow at step 224 : 3.7092061506874214e-68
# underflow at step 225 : 1.8546030753437107e-68
# underflow at step 226 : 9.273015376718553e-69
# underflow at step 227 : 4.636507688359277e-69
# underflow at step 228 : 2.3182538441796384e-69
# underflow at step 229 : 1.1591269220898192e-69
# underflow at step 230 : 5.795634610449096e-70
# underflow at step 231 : 2.897817305224548e-70
# underflow at step 232 : 1.448908652612274e-70
# underflow at step 233 : 7.24454326306137e-71
# underflow at step 234 : 3.622271631530685e-71
# underflow at step 235 : 1.8111358157653425e-71
# underflow at step 236 : 9.055679078826712e-72
# underflow at step 237 : 4.527839539413356e-72
# underflow at step 238 : 2.263919769706678e-72
# underflow at step 239 : 1.131959884853339e-72
# underflow at step 240 : 5.659799424266695e-73
# underflow at step 241 : 2.8298997121333476e-73
# underflow at step 242 : 1.4149498560666738e-73
# underflow at step 243 : 7.074749280333369e-74
# underflow at step 244 : 3.5373746401666845e-74
# underflow at step 245 : 1.7686873200833423e-74
# underflow at step 246 : 8.843436600416711e-75
# underflow at step 247 : 4.421718300208356e-75
# underflow at step 248 : 2.210859150104178e-75
# underflow at step 249 : 1.105429575052089e-75
# underflow at step 250 : 5.527147875260445e-76
# underflow at step 251 : 2.7635739376302223e-76
# underflow at step 252 : 1.3817869688151111e-76
# underflow at step 253 : 6.908934844075556e-77
# underflow at step 254 : 3.454467422037778e-77
# underflow at step 255 : 1.727233711018889e-77
# underflow at step 256 : 8.636168555094445e-78
# underflow at step 257 : 4.3180842775472223e-78
# underflow at step 258 : 2.1590421387736112e-78
# underflow at step 259 : 1.0795210693868056e-78
# underflow at step 260 : 5.397605346934028e-79
# underflow at step 261 : 2.698802673467014e-79
# underflow at step 262 : 1.349401336733507e-79
# underflow at step 263 : 6.747006683667535e-80
# underflow at step 264 : 3.3735033418337674e-80
# underflow at step 265 : 1.6867516709168837e-80
# underflow at step 266 : 8.433758354584419e-81
# underflow at step 267 : 4.2168791772922093e-81
# underflow at step 268 : 2.1084395886461046e-81
# underflow at step 269 : 1.0542197943230523e-81
# underflow at step 270 : 5.271098971615262e-82
# underflow at step 271 : 2.635549485807631e-82
# underflow at step 272 : 1.3177747429038154e-82
# underflow at step 273 : 6.588873714519077e-83
# underflow at step 274 : 3.2944368572595385e-83
# underflow at step 275 : 1.6472184286297693e-83
# underflow at step 276 : 8.236092143148846e-84
# underflow at step 277 : 4.118046071574423e-84
# underflow at step 278 : 2.0590230357872116e-84
# underflow at step 279 : 1.0295115178936058e-84
# underflow at step 280 : 5.147557589468029e-85
# underflow at step 281 : 2.5737787947340145e-85
# underflow at step 282 : 1.2868893973670072e-85
# underflow at step 283 : 6.434446986835036e-86
# underflow at step 284 : 3.217223493417518e-86
# underflow at step 285 : 1.608611746708759e-86
# underflow at step 286 : 8.043058733543795e-87
# underflow at step 287 : 4.021529366771898e-87
# underflow at step 288 : 2.010764683385949e-87
# underflow at step 289 : 1.0053823416929744e-87
# underflow at step 290 : 5.026911708464872e-88
# underflow at step 291 : 2.513455854232436e-88
# underflow at step 292 : 1.256727927116218e-88
# underflow at step 293 : 6.28363963558109e-89
# underflow at step 294 : 3.141819817790545e-89
# underflow at step 295 : 1.5709099088952725e-89
# underflow at step 296 : 7.854549544476363e-90
# underflow at step 297 : 3.9272747722381812e-90
# underflow at step 298 : 1.9636373861190906e-90
# underflow at step 299 : 9.818186930595453e-91
# underflow at step 300 : 4.909093465297727e-91
# underflow at step 301 : 2.4545467326488633e-91
# underflow at step 302 : 1.2272733663244316e-91
# underflow at step 303 : 6.136366831622158e-92
# underflow at step 304 : 3.068183415811079e-92
# underflow at step 305 : 1.5340917079055395e-92
# underflow at step 306 : 7.670458539527698e-93
# underflow at step 307 : 3.835229269763849e-93
# underflow at step 308 : 1.9176146348819244e-93
# underflow at step 309 : 9.588073174409622e-94
# underflow at step 310 : 4.794036587204811e-94
# underflow at step 311 : 2.3970182936024055e-94
# underflow at step 312 : 1.1985091468012028e-94
# underflow at step 313 : 5.992545734006014e-95
# underflow at step 314 : 2.996272867003007e-95
# underflow at step 315 : 1.4981364335015035e-95
# underflow at step 316 : 7.490682167507517e-96
# underflow at step 317 : 3.745341083753759e-96
# underflow at step 318 : 1.8726705418768793e-96
# underflow at step 319 : 9.363352709384397e-97
# underflow at step 320 : 4.6816763546921983e-97
# underflow at step 321 : 2.3408381773460992e-97
# underflow at step 322 : 1.1704190886730496e-97
# underflow at step 323 : 5.852095443365248e-98
# underflow at step 324 : 2.926047721682624e-98
# underflow at step 325 : 1.463023860841312e-98
# underflow at step 326 : 7.31511930420656e-99
# underflow at step 327 : 3.65755965210328e-99
# underflow at step 328 : 1.82877982605164e-99
# underflow at step 329 : 9.1438991302582e-100
# underflow at step 330 : 4.5719495651291e-100
# underflow at step 331 : 2.28597478256455e-100
# underflow at step 332 : 1.142987391282275e-100
# underflow at step 333 : 5.714936956411375e-101
# underflow at step 334 : 2.8574684782056875e-101
# underflow at step 335 : 1.4287342391028437e-101
# underflow at step 336 : 7.143671195514219e-102
# underflow at step 337 : 3.5718355977571093e-102
# underflow at step 338 : 1.7859177988785547e-102
# underflow at step 339 : 8.929588994392773e-103
# underflow at step 340 : 4.464794497196387e-103
# underflow at step 341 : 2.2323972485981933e-103
# underflow at step 342 : 1.1161986242990967e-103
# underflow at step 343 : 5.5809931214954833e-104
# underflow at step 344 : 2.7904965607477417e-104
# underflow at step 345 : 1.3952482803738708e-104
# underflow at step 346 : 6.976241401869354e-105
# underflow at step 347 : 3.488120700934677e-105
# underflow at step 348 : 1.7440603504673385e-105
# underflow at step 349 : 8.720301752336693e-106
# underflow at step 350 : 4.3601508761683463e-106
# underflow at step 351 : 2.1800754380841732e-106
# underflow at step 352 : 1.0900377190420866e-106
# underflow at step 353 : 5.450188595210433e-107
# underflow at step 354 : 2.7250942976052165e-107
# underflow at step 355 : 1.3625471488026082e-107
# underflow at step 356 : 6.812735744013041e-108
# underflow at step 357 : 3.4063678720065206e-108
# underflow at step 358 : 1.7031839360032603e-108
# underflow at step 359 : 8.515919680016301e-109
# underflow at step 360 : 4.257959840008151e-109
# underflow at step 361 : 2.1289799200040754e-109
# underflow at step 362 : 1.0644899600020377e-109
# underflow at step 363 : 5.3224498000101884e-110
# underflow at step 364 : 2.6612249000050942e-110
# underflow at step 365 : 1.3306124500025471e-110
# underflow at step 366 : 6.653062250012736e-111
# underflow at step 367 : 3.326531125006368e-111
# underflow at step 368 : 1.663265562503184e-111
# underflow at step 369 : 8.31632781251592e-112
# underflow at step 370 : 4.15816390625796e-112
# underflow at step 371 : 2.07908195312898e-112
# underflow at step 372 : 1.03954097656449e-112
# underflow at step 373 : 5.19770488282245e-113
# underflow at step 374 : 2.598852441411225e-113
# underflow at step 375 : 1.2994262207056124e-113
# underflow at step 376 : 6.497131103528062e-114
# underflow at step 377 : 3.248565551764031e-114
# underflow at step 378 : 1.6242827758820155e-114
# underflow at step 379 : 8.121413879410078e-115
# underflow at step 380 : 4.060706939705039e-115
# underflow at step 381 : 2.0303534698525194e-115
# underflow at step 382 : 1.0151767349262597e-115
# underflow at step 383 : 5.075883674631299e-116
# underflow at step 384 : 2.5379418373156492e-116
# underflow at step 385 : 1.2689709186578246e-116
# underflow at step 386 : 6.344854593289123e-117
# underflow at step 387 : 3.1724272966445615e-117
# underflow at step 388 : 1.5862136483222808e-117
# underflow at step 389 : 7.931068241611404e-118
# underflow at step 390 : 3.965534120805702e-118
# underflow at step 391 : 1.982767060402851e-118
# underflow at step 392 : 9.913835302014255e-119
# underflow at step 393 : 4.9569176510071274e-119
# underflow at step 394 : 2.4784588255035637e-119
# underflow at step 395 : 1.2392294127517818e-119
# underflow at step 396 : 6.196147063758909e-120
# underflow at step 397 : 3.0980735318794546e-120
# underflow at step 398 : 1.5490367659397273e-120
# underflow at step 399 : 7.745183829698637e-121
# underflow at step 400 : 3.8725919148493183e-121
# underflow at step 401 : 1.9362959574246591e-121
# underflow at step 402 : 9.681479787123296e-122
# underflow at step 403 : 4.840739893561648e-122
# underflow at step 404 : 2.420369946780824e-122
# underflow at step 405 : 1.210184973390412e-122
# underflow at step 406 : 6.05092486695206e-123
# underflow at step 407 : 3.02546243347603e-123
# underflow at step 408 : 1.512731216738015e-123
# underflow at step 409 : 7.563656083690075e-124
# underflow at step 410 : 3.7818280418450374e-124
# underflow at step 411 : 1.8909140209225187e-124
# underflow at step 412 : 9.454570104612593e-125
# underflow at step 413 : 4.727285052306297e-125
# underflow at step 414 : 2.3636425261531484e-125
# underflow at step 415 : 1.1818212630765742e-125
# underflow at step 416 : 5.909106315382871e-126
# underflow at step 417 : 2.9545531576914354e-126
# underflow at step 418 : 1.4772765788457177e-126
# underflow at step 419 : 7.386382894228589e-127
# underflow at step 420 : 3.6931914471142943e-127
# underflow at step 421 : 1.8465957235571472e-127
# underflow at step 422 : 9.232978617785736e-128
# underflow at step 423 : 4.616489308892868e-128
# underflow at step 424 : 2.308244654446434e-128
# underflow at step 425 : 1.154122327223217e-128
# underflow at step 426 : 5.770611636116085e-129
# underflow at step 427 : 2.8853058180580424e-129
# underflow at step 428 : 1.4426529090290212e-129
# underflow at step 429 : 7.213264545145106e-130
# underflow at step 430 : 3.606632272572553e-130
# underflow at step 431 : 1.8033161362862765e-130
# underflow at step 432 : 9.016580681431383e-131
# underflow at step 433 : 4.5082903407156913e-131
# underflow at step 434 : 2.2541451703578456e-131
# underflow at step 435 : 1.1270725851789228e-131
# underflow at step 436 : 5.635362925894614e-132
# underflow at step 437 : 2.817681462947307e-132
# underflow at step 438 : 1.4088407314736535e-132
# underflow at step 439 : 7.044203657368268e-133
# underflow at step 440 : 3.522101828684134e-133
# underflow at step 441 : 1.761050914342067e-133
# underflow at step 442 : 8.805254571710335e-134
# underflow at step 443 : 4.4026272858551673e-134
# underflow at step 444 : 2.2013136429275836e-134
# underflow at step 445 : 1.1006568214637918e-134
# underflow at step 446 : 5.503284107318959e-135
# underflow at step 447 : 2.7516420536594796e-135
# underflow at step 448 : 1.3758210268297398e-135
# underflow at step 449 : 6.879105134148699e-136
# underflow at step 450 : 3.4395525670743494e-136
# underflow at step 451 : 1.7197762835371747e-136
# underflow at step 452 : 8.598881417685874e-137
# underflow at step 453 : 4.299440708842937e-137
# underflow at step 454 : 2.1497203544214684e-137
# underflow at step 455 : 1.0748601772107342e-137
# underflow at step 456 : 5.374300886053671e-138
# underflow at step 457 : 2.6871504430268355e-138
# underflow at step 458 : 1.3435752215134178e-138
# underflow at step 459 : 6.717876107567089e-139
# underflow at step 460 : 3.3589380537835444e-139
# underflow at step 461 : 1.6794690268917722e-139
# underflow at step 462 : 8.397345134458861e-140
# underflow at step 463 : 4.1986725672294305e-140
# underflow at step 464 : 2.0993362836147152e-140
# underflow at step 465 : 1.0496681418073576e-140
# underflow at step 466 : 5.248340709036788e-141
# underflow at step 467 : 2.624170354518394e-141
# underflow at step 468 : 1.312085177259197e-141
# underflow at step 469 : 6.560425886295985e-142
# underflow at step 470 : 3.2802129431479926e-142
# underflow at step 471 : 1.6401064715739963e-142
# underflow at step 472 : 8.200532357869981e-143
# underflow at step 473 : 4.100266178934991e-143
# underflow at step 474 : 2.0501330894674953e-143
# underflow at step 475 : 1.0250665447337477e-143
# underflow at step 476 : 5.1253327236687384e-144
# underflow at step 477 : 2.5626663618343692e-144
# underflow at step 478 : 1.2813331809171846e-144
# underflow at step 479 : 6.406665904585923e-145
# underflow at step 480 : 3.2033329522929615e-145
# underflow at step 481 : 1.6016664761464807e-145
# underflow at step 482 : 8.008332380732404e-146
# underflow at step 483 : 4.004166190366202e-146
# underflow at step 484 : 2.002083095183101e-146
# underflow at step 485 : 1.0010415475915505e-146
# underflow at step 486 : 5.0052077379577523e-147
# underflow at step 487 : 2.5026038689788762e-147
# underflow at step 488 : 1.2513019344894381e-147
# underflow at step 489 : 6.256509672447191e-148
# underflow at step 490 : 3.1282548362235952e-148
# underflow at step 491 : 1.5641274181117976e-148
# underflow at step 492 : 7.820637090558988e-149
# underflow at step 493 : 3.910318545279494e-149
# underflow at step 494 : 1.955159272639747e-149
# underflow at step 495 : 9.775796363198735e-150
# underflow at step 496 : 4.887898181599368e-150
# underflow at step 497 : 2.443949090799684e-150
# underflow at step 498 : 1.221974545399842e-150
# underflow at step 499 : 6.10987272699921e-151
# underflow at step 500 : 3.054936363499605e-151
# underflow at step 501 : 1.5274681817498023e-151
# underflow at step 502 : 7.637340908749012e-152
# underflow at step 503 : 3.818670454374506e-152
# underflow at step 504 : 1.909335227187253e-152
# underflow at step 505 : 9.546676135936265e-153
# underflow at step 506 : 4.7733380679681323e-153
# underflow at step 507 : 2.3866690339840662e-153
# underflow at step 508 : 1.1933345169920331e-153
# underflow at step 509 : 5.966672584960166e-154
# underflow at step 510 : 2.983336292480083e-154
# underflow at step 511 : 1.4916681462400413e-154
# underflow at step 512 : 7.458340731200207e-155
# underflow at step 513 : 3.7291703656001034e-155
# underflow at step 514 : 1.8645851828000517e-155
# underflow at step 515 : 9.322925914000258e-156
# underflow at step 516 : 4.661462957000129e-156
# underflow at step 517 : 2.3307314785000646e-156
# underflow at step 518 : 1.1653657392500323e-156
# underflow at step 519 : 5.826828696250162e-157
# underflow at step 520 : 2.913414348125081e-157
# underflow at step 521 : 1.4567071740625404e-157
# underflow at step 522 : 7.283535870312702e-158
# underflow at step 523 : 3.641767935156351e-158
# underflow at step 524 : 1.8208839675781755e-158
# underflow at step 525 : 9.104419837890877e-159
# underflow at step 526 : 4.552209918945439e-159
# underflow at step 527 : 2.2761049594727193e-159
# underflow at step 528 : 1.1380524797363597e-159
# underflow at step 529 : 5.6902623986817984e-160
# underflow at step 530 : 2.8451311993408992e-160
# underflow at step 531 : 1.4225655996704496e-160
# underflow at step 532 : 7.112827998352248e-161
# underflow at step 533 : 3.556413999176124e-161
# underflow at step 534 : 1.778206999588062e-161
# underflow at step 535 : 8.89103499794031e-162
# underflow at step 536 : 4.445517498970155e-162
# underflow at step 537 : 2.2227587494850775e-162
# underflow at step 538 : 1.1113793747425387e-162
# underflow at step 539 : 5.556896873712694e-163
# underflow at step 540 : 2.778448436856347e-163
# underflow at step 541 : 1.3892242184281734e-163
# underflow at step 542 : 6.946121092140867e-164
# underflow at step 543 : 3.4730605460704336e-164
# underflow at step 544 : 1.7365302730352168e-164
# underflow at step 545 : 8.682651365176084e-165
# underflow at step 546 : 4.341325682588042e-165
# underflow at step 547 : 2.170662841294021e-165
# underflow at step 548 : 1.0853314206470105e-165
# underflow at step 549 : 5.426657103235053e-166
# underflow at step 550 : 2.7133285516175262e-166
# underflow at step 551 : 1.3566642758087631e-166
# underflow at step 552 : 6.783321379043816e-167
# underflow at step 553 : 3.391660689521908e-167
# underflow at step 554 : 1.695830344760954e-167
# underflow at step 555 : 8.47915172380477e-168
# underflow at step 556 : 4.239575861902385e-168
# underflow at step 557 : 2.1197879309511924e-168
# underflow at step 558 : 1.0598939654755962e-168
# underflow at step 559 : 5.299469827377981e-169
# underflow at step 560 : 2.6497349136889905e-169
# underflow at step 561 : 1.3248674568444952e-169
# underflow at step 562 : 6.624337284222476e-170
# underflow at step 563 : 3.312168642111238e-170
# underflow at step 564 : 1.656084321055619e-170
# underflow at step 565 : 8.280421605278095e-171
# underflow at step 566 : 4.140210802639048e-171
# underflow at step 567 : 2.070105401319524e-171
# underflow at step 568 : 1.035052700659762e-171
# underflow at step 569 : 5.17526350329881e-172
# underflow at step 570 : 2.587631751649405e-172
# underflow at step 571 : 1.2938158758247024e-172
# underflow at step 572 : 6.469079379123512e-173
# underflow at step 573 : 3.234539689561756e-173
# underflow at step 574 : 1.617269844780878e-173
# underflow at step 575 : 8.08634922390439e-174
# underflow at step 576 : 4.043174611952195e-174
# underflow at step 577 : 2.0215873059760975e-174
# underflow at step 578 : 1.0107936529880487e-174
# underflow at step 579 : 5.053968264940244e-175
# underflow at step 580 : 2.526984132470122e-175
# underflow at step 581 : 1.263492066235061e-175
# underflow at step 582 : 6.317460331175305e-176
# underflow at step 583 : 3.1587301655876523e-176
# underflow at step 584 : 1.5793650827938261e-176
# underflow at step 585 : 7.896825413969131e-177
# underflow at step 586 : 3.9484127069845653e-177
# underflow at step 587 : 1.9742063534922827e-177
# underflow at step 588 : 9.871031767461413e-178
# underflow at step 589 : 4.935515883730707e-178
# underflow at step 590 : 2.4677579418653533e-178
# underflow at step 591 : 1.2338789709326767e-178
# underflow at step 592 : 6.169394854663383e-179
# underflow at step 593 : 3.084697427331692e-179
# underflow at step 594 : 1.542348713665846e-179
# underflow at step 595 : 7.71174356832923e-180
# underflow at step 596 : 3.855871784164615e-180
# underflow at step 597 : 1.9279358920823073e-180
# underflow at step 598 : 9.639679460411536e-181
# underflow at step 599 : 4.819839730205768e-181
# underflow at step 600 : 2.409919865102884e-181
# underflow at step 601 : 1.204959932551442e-181
# underflow at step 602 : 6.02479966275721e-182
# underflow at step 603 : 3.012399831378605e-182
# underflow at step 604 : 1.5061999156893026e-182
# underflow at step 605 : 7.530999578446513e-183
# underflow at step 606 : 3.7654997892232564e-183
# underflow at step 607 : 1.8827498946116282e-183
# underflow at step 608 : 9.413749473058141e-184
# underflow at step 609 : 4.706874736529071e-184
# underflow at step 610 : 2.3534373682645353e-184
# underflow at step 611 : 1.1767186841322676e-184
# underflow at step 612 : 5.883593420661338e-185
# underflow at step 613 : 2.941796710330669e-185
# underflow at step 614 : 1.4708983551653345e-185
# underflow at step 615 : 7.354491775826673e-186
# underflow at step 616 : 3.6772458879133364e-186
# underflow at step 617 : 1.8386229439566682e-186
# underflow at step 618 : 9.193114719783341e-187
# underflow at step 619 : 4.5965573598916705e-187
# underflow at step 620 : 2.2982786799458352e-187
# underflow at step 621 : 1.1491393399729176e-187
# underflow at step 622 : 5.745696699864588e-188
# underflow at step 623 : 2.872848349932294e-188
# underflow at step 624 : 1.436424174966147e-188
# underflow at step 625 : 7.182120874830735e-189
# underflow at step 626 : 3.5910604374153675e-189
# underflow at step 627 : 1.7955302187076838e-189
# underflow at step 628 : 8.977651093538419e-190
# underflow at step 629 : 4.4888255467692094e-190
# underflow at step 630 : 2.2444127733846047e-190
# underflow at step 631 : 1.1222063866923024e-190
# underflow at step 632 : 5.611031933461512e-191
# underflow at step 633 : 2.805515966730756e-191
# underflow at step 634 : 1.402757983365378e-191
# underflow at step 635 : 7.01378991682689e-192
# underflow at step 636 : 3.506894958413445e-192
# underflow at step 637 : 1.7534474792067224e-192
# underflow at step 638 : 8.767237396033612e-193
# underflow at step 639 : 4.383618698016806e-193
# underflow at step 640 : 2.191809349008403e-193
# underflow at step 641 : 1.0959046745042015e-193
# underflow at step 642 : 5.479523372521008e-194
# underflow at step 643 : 2.739761686260504e-194
# underflow at step 644 : 1.369880843130252e-194
# underflow at step 645 : 6.84940421565126e-195
# underflow at step 646 : 3.42470210782563e-195
# underflow at step 647 : 1.712351053912815e-195
# underflow at step 648 : 8.561755269564074e-196
# underflow at step 649 : 4.280877634782037e-196
# underflow at step 650 : 2.1404388173910186e-196
# underflow at step 651 : 1.0702194086955093e-196
# underflow at step 652 : 5.351097043477547e-197
# underflow at step 653 : 2.6755485217387732e-197
# underflow at step 654 : 1.3377742608693866e-197
# underflow at step 655 : 6.688871304346933e-198
# underflow at step 656 : 3.3444356521734666e-198
# underflow at step 657 : 1.6722178260867333e-198
# underflow at step 658 : 8.361089130433666e-199
# underflow at step 659 : 4.180544565216833e-199
# underflow at step 660 : 2.0902722826084166e-199
# underflow at step 661 : 1.0451361413042083e-199
# underflow at step 662 : 5.225680706521042e-200
# underflow at step 663 : 2.612840353260521e-200
# underflow at step 664 : 1.3064201766302604e-200
# underflow at step 665 : 6.532100883151302e-201
# underflow at step 666 : 3.266050441575651e-201
# underflow at step 667 : 1.6330252207878255e-201
# underflow at step 668 : 8.165126103939127e-202
# underflow at step 669 : 4.082563051969564e-202
# underflow at step 670 : 2.041281525984782e-202
# underflow at step 671 : 1.020640762992391e-202
# underflow at step 672 : 5.103203814961955e-203
# underflow at step 673 : 2.5516019074809773e-203
# underflow at step 674 : 1.2758009537404886e-203
# underflow at step 675 : 6.379004768702443e-204
# underflow at step 676 : 3.1895023843512216e-204
# underflow at step 677 : 1.5947511921756108e-204
# underflow at step 678 : 7.973755960878054e-205
# underflow at step 679 : 3.986877980439027e-205
# underflow at step 680 : 1.9934389902195135e-205
# underflow at step 681 : 9.967194951097568e-206
# underflow at step 682 : 4.983597475548784e-206
# underflow at step 683 : 2.491798737774392e-206
# underflow at step 684 : 1.245899368887196e-206
# underflow at step 685 : 6.22949684443598e-207
# underflow at step 686 : 3.11474842221799e-207
# underflow at step 687 : 1.557374211108995e-207
# underflow at step 688 : 7.786871055544975e-208
# underflow at step 689 : 3.8934355277724873e-208
# underflow at step 690 : 1.9467177638862437e-208
# underflow at step 691 : 9.733588819431218e-209
# underflow at step 692 : 4.866794409715609e-209
# underflow at step 693 : 2.4333972048578046e-209
# underflow at step 694 : 1.2166986024289023e-209
# underflow at step 695 : 6.083493012144512e-210
# underflow at step 696 : 3.041746506072256e-210
# underflow at step 697 : 1.520873253036128e-210
# underflow at step 698 : 7.60436626518064e-211
# underflow at step 699 : 3.80218313259032e-211
# underflow at step 700 : 1.90109156629516e-211
# underflow at step 701 : 9.5054578314758e-212
# underflow at step 702 : 4.7527289157379e-212
# underflow at step 703 : 2.37636445786895e-212
# underflow at step 704 : 1.188182228934475e-212
# underflow at step 705 : 5.940911144672375e-213
# underflow at step 706 : 2.9704555723361872e-213
# underflow at step 707 : 1.4852277861680936e-213
# underflow at step 708 : 7.426138930840468e-214
# underflow at step 709 : 3.713069465420234e-214
# underflow at step 710 : 1.856534732710117e-214
# underflow at step 711 : 9.282673663550585e-215
# underflow at step 712 : 4.641336831775293e-215
# underflow at step 713 : 2.3206684158876463e-215
# underflow at step 714 : 1.1603342079438231e-215
# underflow at step 715 : 5.801671039719116e-216
# underflow at step 716 : 2.900835519859558e-216
# underflow at step 717 : 1.450417759929779e-216
# underflow at step 718 : 7.252088799648895e-217
# underflow at step 719 : 3.6260443998244473e-217
# underflow at step 720 : 1.8130221999122236e-217
# underflow at step 721 : 9.065110999561118e-218
# underflow at step 722 : 4.532555499780559e-218
# underflow at step 723 : 2.2662777498902796e-218
# underflow at step 724 : 1.1331388749451398e-218
# underflow at step 725 : 5.665694374725699e-219
# underflow at step 726 : 2.8328471873628494e-219
# underflow at step 727 : 1.4164235936814247e-219
# underflow at step 728 : 7.082117968407124e-220
# underflow at step 729 : 3.541058984203562e-220
# underflow at step 730 : 1.770529492101781e-220
# underflow at step 731 : 8.852647460508905e-221
# underflow at step 732 : 4.4263237302544523e-221
# underflow at step 733 : 2.2131618651272261e-221
# underflow at step 734 : 1.1065809325636131e-221
# underflow at step 735 : 5.5329046628180653e-222
# underflow at step 736 : 2.7664523314090327e-222
# underflow at step 737 : 1.3832261657045163e-222
# underflow at step 738 : 6.916130828522582e-223
# underflow at step 739 : 3.458065414261291e-223
# underflow at step 740 : 1.7290327071306454e-223
# underflow at step 741 : 8.645163535653227e-224
# underflow at step 742 : 4.322581767826614e-224
# underflow at step 743 : 2.161290883913307e-224
# underflow at step 744 : 1.0806454419566534e-224
# underflow at step 745 : 5.403227209783267e-225
# underflow at step 746 : 2.7016136048916335e-225
# underflow at step 747 : 1.3508068024458167e-225
# underflow at step 748 : 6.754034012229084e-226
# underflow at step 749 : 3.377017006114542e-226
# underflow at step 750 : 1.688508503057271e-226
# underflow at step 751 : 8.442542515286355e-227
# underflow at step 752 : 4.2212712576431773e-227
# underflow at step 753 : 2.1106356288215886e-227
# underflow at step 754 : 1.0553178144107943e-227
# underflow at step 755 : 5.276589072053972e-228
# underflow at step 756 : 2.638294536026986e-228
# underflow at step 757 : 1.319147268013493e-228
# underflow at step 758 : 6.595736340067465e-229
# underflow at step 759 : 3.2978681700337323e-229
# underflow at step 760 : 1.6489340850168661e-229
# underflow at step 761 : 8.244670425084331e-230
# underflow at step 762 : 4.1223352125421653e-230
# underflow at step 763 : 2.0611676062710827e-230
# underflow at step 764 : 1.0305838031355413e-230
# underflow at step 765 : 5.152919015677707e-231
# underflow at step 766 : 2.5764595078388533e-231
# underflow at step 767 : 1.2882297539194267e-231
# underflow at step 768 : 6.441148769597133e-232
# underflow at step 769 : 3.220574384798567e-232
# underflow at step 770 : 1.6102871923992833e-232
# underflow at step 771 : 8.051435961996417e-233
# underflow at step 772 : 4.0257179809982083e-233
# underflow at step 773 : 2.0128589904991042e-233
# underflow at step 774 : 1.0064294952495521e-233
# underflow at step 775 : 5.0321474762477604e-234
# underflow at step 776 : 2.5160737381238802e-234
# underflow at step 777 : 1.2580368690619401e-234
# underflow at step 778 : 6.290184345309701e-235
# underflow at step 779 : 3.1450921726548502e-235
# underflow at step 780 : 1.5725460863274251e-235
# underflow at step 781 : 7.862730431637126e-236
# underflow at step 782 : 3.931365215818563e-236
# underflow at step 783 : 1.9656826079092814e-236
# underflow at step 784 : 9.828413039546407e-237
# underflow at step 785 : 4.914206519773204e-237
# underflow at step 786 : 2.457103259886602e-237
# underflow at step 787 : 1.228551629943301e-237
# underflow at step 788 : 6.142758149716505e-238
# underflow at step 789 : 3.0713790748582522e-238
# underflow at step 790 : 1.5356895374291261e-238
# underflow at step 791 : 7.678447687145631e-239
# underflow at step 792 : 3.8392238435728152e-239
# underflow at step 793 : 1.9196119217864076e-239
# underflow at step 794 : 9.598059608932038e-240
# underflow at step 795 : 4.799029804466019e-240
# underflow at step 796 : 2.3995149022330095e-240
# underflow at step 797 : 1.1997574511165048e-240
# underflow at step 798 : 5.998787255582524e-241
# underflow at step 799 : 2.999393627791262e-241
# underflow at step 800 : 1.499696813895631e-241
# underflow at step 801 : 7.498484069478155e-242
# underflow at step 802 : 3.7492420347390774e-242
# underflow at step 803 : 1.8746210173695387e-242
# underflow at step 804 : 9.373105086847693e-243
# underflow at step 805 : 4.686552543423847e-243
# underflow at step 806 : 2.3432762717119234e-243
# underflow at step 807 : 1.1716381358559617e-243
# underflow at step 808 : 5.858190679279809e-244
# underflow at step 809 : 2.9290953396399042e-244
# underflow at step 810 : 1.4645476698199521e-244
# underflow at step 811 : 7.322738349099761e-245
# underflow at step 812 : 3.6613691745498803e-245
# underflow at step 813 : 1.8306845872749401e-245
# underflow at step 814 : 9.153422936374701e-246
# underflow at step 815 : 4.5767114681873503e-246
# underflow at step 816 : 2.2883557340936752e-246
# underflow at step 817 : 1.1441778670468376e-246
# underflow at step 818 : 5.720889335234188e-247
# underflow at step 819 : 2.860444667617094e-247
# underflow at step 820 : 1.430222333808547e-247
# underflow at step 821 : 7.151111669042735e-248
# underflow at step 822 : 3.5755558345213674e-248
# underflow at step 823 : 1.7877779172606837e-248
# underflow at step 824 : 8.938889586303419e-249
# underflow at step 825 : 4.4694447931517093e-249
# underflow at step 826 : 2.2347223965758547e-249
# underflow at step 827 : 1.1173611982879273e-249
# underflow at step 828 : 5.586805991439637e-250
# underflow at step 829 : 2.7934029957198183e-250
# underflow at step 830 : 1.3967014978599092e-250
# underflow at step 831 : 6.983507489299546e-251
# underflow at step 832 : 3.491753744649773e-251
# underflow at step 833 : 1.7458768723248864e-251
# underflow at step 834 : 8.729384361624432e-252
# underflow at step 835 : 4.364692180812216e-252
# underflow at step 836 : 2.182346090406108e-252
# underflow at step 837 : 1.091173045203054e-252
# underflow at step 838 : 5.45586522601527e-253
# underflow at step 839 : 2.727932613007635e-253
# underflow at step 840 : 1.3639663065038175e-253
# underflow at step 841 : 6.819831532519088e-254
# underflow at step 842 : 3.409915766259544e-254
# underflow at step 843 : 1.704957883129772e-254
# underflow at step 844 : 8.52478941564886e-255
# underflow at step 845 : 4.26239470782443e-255
# underflow at step 846 : 2.131197353912215e-255
# underflow at step 847 : 1.0655986769561075e-255
# underflow at step 848 : 5.327993384780537e-256
# underflow at step 849 : 2.6639966923902686e-256
# underflow at step 850 : 1.3319983461951343e-256
# underflow at step 851 : 6.659991730975672e-257
# underflow at step 852 : 3.329995865487836e-257
# underflow at step 853 : 1.664997932743918e-257
# underflow at step 854 : 8.32498966371959e-258
# underflow at step 855 : 4.162494831859795e-258
# underflow at step 856 : 2.0812474159298974e-258
# underflow at step 857 : 1.0406237079649487e-258
# underflow at step 858 : 5.2031185398247434e-259
# underflow at step 859 : 2.6015592699123717e-259
# underflow at step 860 : 1.3007796349561859e-259
# underflow at step 861 : 6.503898174780929e-260
# underflow at step 862 : 3.2519490873904646e-260
# underflow at step 863 : 1.6259745436952323e-260
# underflow at step 864 : 8.129872718476162e-261
# underflow at step 865 : 4.064936359238081e-261
# underflow at step 866 : 2.0324681796190404e-261
# underflow at step 867 : 1.0162340898095202e-261
# underflow at step 868 : 5.081170449047601e-262
# underflow at step 869 : 2.5405852245238005e-262
# underflow at step 870 : 1.2702926122619002e-262
# underflow at step 871 : 6.351463061309501e-263
# underflow at step 872 : 3.1757315306547506e-263
# underflow at step 873 : 1.5878657653273753e-263
# underflow at step 874 : 7.939328826636877e-264
# underflow at step 875 : 3.9696644133184383e-264
# underflow at step 876 : 1.9848322066592191e-264
# underflow at step 877 : 9.924161033296096e-265
# underflow at step 878 : 4.962080516648048e-265
# underflow at step 879 : 2.481040258324024e-265
# underflow at step 880 : 1.240520129162012e-265
# underflow at step 881 : 6.20260064581006e-266
# underflow at step 882 : 3.10130032290503e-266
# underflow at step 883 : 1.550650161452515e-266
# underflow at step 884 : 7.753250807262575e-267
# underflow at step 885 : 3.8766254036312874e-267
# underflow at step 886 : 1.9383127018156437e-267
# underflow at step 887 : 9.691563509078218e-268
# underflow at step 888 : 4.845781754539109e-268
# underflow at step 889 : 2.4228908772695546e-268
# underflow at step 890 : 1.2114454386347773e-268
# underflow at step 891 : 6.057227193173887e-269
# underflow at step 892 : 3.0286135965869433e-269
# underflow at step 893 : 1.5143067982934716e-269
# underflow at step 894 : 7.571533991467358e-270
# underflow at step 895 : 3.785766995733679e-270
# underflow at step 896 : 1.8928834978668395e-270
# underflow at step 897 : 9.464417489334198e-271
# underflow at step 898 : 4.732208744667099e-271
# underflow at step 899 : 2.3661043723335494e-271
# underflow at step 900 : 1.1830521861667747e-271
# underflow at step 901 : 5.915260930833874e-272
# underflow at step 902 : 2.957630465416937e-272
# underflow at step 903 : 1.4788152327084684e-272
# underflow at step 904 : 7.394076163542342e-273
# underflow at step 905 : 3.697038081771171e-273
# underflow at step 906 : 1.8485190408855855e-273
# underflow at step 907 : 9.242595204427927e-274
# underflow at step 908 : 4.621297602213964e-274
# underflow at step 909 : 2.310648801106982e-274
# underflow at step 910 : 1.155324400553491e-274
# underflow at step 911 : 5.776622002767455e-275
# underflow at step 912 : 2.8883110013837273e-275
# underflow at step 913 : 1.4441555006918637e-275
# underflow at step 914 : 7.220777503459318e-276
# underflow at step 915 : 3.610388751729659e-276
# underflow at step 916 : 1.8051943758648296e-276
# underflow at step 917 : 9.025971879324148e-277
# underflow at step 918 : 4.512985939662074e-277
# underflow at step 919 : 2.256492969831037e-277
# underflow at step 920 : 1.1282464849155185e-277
# underflow at step 921 : 5.641232424577593e-278
# underflow at step 922 : 2.8206162122887962e-278
# underflow at step 923 : 1.4103081061443981e-278
# underflow at step 924 : 7.051540530721991e-279
# underflow at step 925 : 3.5257702653609953e-279
# underflow at step 926 : 1.7628851326804976e-279
# underflow at step 927 : 8.814425663402488e-280
# underflow at step 928 : 4.407212831701244e-280
# underflow at step 929 : 2.203606415850622e-280
# underflow at step 930 : 1.101803207925311e-280
# underflow at step 931 : 5.509016039626555e-281
# underflow at step 932 : 2.7545080198132776e-281
# underflow at step 933 : 1.3772540099066388e-281
# underflow at step 934 : 6.886270049533194e-282
# underflow at step 935 : 3.443135024766597e-282
# underflow at step 936 : 1.7215675123832985e-282
# underflow at step 937 : 8.607837561916492e-283
# underflow at step 938 : 4.303918780958246e-283
# underflow at step 939 : 2.151959390479123e-283
# underflow at step 940 : 1.0759796952395615e-283
# underflow at step 941 : 5.379898476197808e-284
# underflow at step 942 : 2.689949238098904e-284
# underflow at step 943 : 1.344974619049452e-284
# underflow at step 944 : 6.72487309524726e-285
# underflow at step 945 : 3.36243654762363e-285
# underflow at step 946 : 1.681218273811815e-285
# underflow at step 947 : 8.406091369059075e-286
# underflow at step 948 : 4.2030456845295373e-286
# underflow at step 949 : 2.1015228422647686e-286
# underflow at step 950 : 1.0507614211323843e-286
# underflow at step 951 : 5.253807105661922e-287
# underflow at step 952 : 2.626903552830961e-287
# underflow at step 953 : 1.3134517764154804e-287
# underflow at step 954 : 6.567258882077402e-288
# underflow at step 955 : 3.283629441038701e-288
# underflow at step 956 : 1.6418147205193505e-288
# underflow at step 957 : 8.209073602596753e-289
# underflow at step 958 : 4.1045368012983762e-289
# underflow at step 959 : 2.0522684006491881e-289
# underflow at step 960 : 1.0261342003245941e-289
# underflow at step 961 : 5.1306710016229703e-290
# underflow at step 962 : 2.5653355008114852e-290
# underflow at step 963 : 1.2826677504057426e-290
# underflow at step 964 : 6.413338752028713e-291
# underflow at step 965 : 3.2066693760143564e-291
# underflow at step 966 : 1.6033346880071782e-291
# underflow at step 967 : 8.016673440035891e-292
# underflow at step 968 : 4.008336720017946e-292
# underflow at step 969 : 2.004168360008973e-292
# underflow at step 970 : 1.0020841800044864e-292
# underflow at step 971 : 5.010420900022432e-293
# underflow at step 972 : 2.505210450011216e-293
# underflow at step 973 : 1.252605225005608e-293
# underflow at step 974 : 6.26302612502804e-294
# underflow at step 975 : 3.13151306251402e-294
# underflow at step 976 : 1.56575653125701e-294
# underflow at step 977 : 7.82878265628505e-295
# underflow at step 978 : 3.914391328142525e-295
# underflow at step 979 : 1.9571956640712625e-295
# underflow at step 980 : 9.785978320356312e-296
# underflow at step 981 : 4.892989160178156e-296
# underflow at step 982 : 2.446494580089078e-296
# underflow at step 983 : 1.223247290044539e-296
# underflow at step 984 : 6.116236450222695e-297
# underflow at step 985 : 3.0581182251113476e-297
# underflow at step 986 : 1.5290591125556738e-297
# underflow at step 987 : 7.645295562778369e-298
# underflow at step 988 : 3.8226477813891845e-298
# underflow at step 989 : 1.9113238906945923e-298
# underflow at step 990 : 9.556619453472961e-299
# underflow at step 991 : 4.778309726736481e-299
# underflow at step 992 : 2.3891548633682403e-299
# underflow at step 993 : 1.1945774316841202e-299
# underflow at step 994 : 5.972887158420601e-300
# underflow at step 995 : 2.9864435792103004e-300
# underflow at step 996 : 1.4932217896051502e-300
# underflow at step 997 : 7.466108948025751e-301
# underflow at step 998 : 3.7330544740128755e-301
# underflow at step 999 : 1.8665272370064378e-301
# underflow at step 1000 : 9.332636185032189e-302
# underflow at step 1001 : 4.6663180925160944e-302
# underflow at step 1002 : 2.3331590462580472e-302
# underflow at step 1003 : 1.1665795231290236e-302
# underflow at step 1004 : 5.832897615645118e-303
# underflow at step 1005 : 2.916448807822559e-303
# underflow at step 1006 : 1.4582244039112795e-303
# underflow at step 1007 : 7.291122019556398e-304
# underflow at step 1008 : 3.645561009778199e-304
# underflow at step 1009 : 1.8227805048890994e-304
# underflow at step 1010 : 9.113902524445497e-305
# underflow at step 1011 : 4.5569512622227484e-305
# underflow at step 1012 : 2.2784756311113742e-305
# underflow at step 1013 : 1.1392378155556871e-305
# underflow at step 1014 : 5.696189077778436e-306
# underflow at step 1015 : 2.848094538889218e-306
# underflow at step 1016 : 1.424047269444609e-306
# underflow at step 1017 : 7.120236347223045e-307
# underflow at step 1018 : 3.5601181736115222e-307
# underflow at step 1019 : 1.7800590868057611e-307
# underflow at step 1020 : 8.900295434028806e-308
# underflow at step 1021 : 4.450147717014403e-308
# underflow at step 1022 : 2.2250738585072014e-308
# underflow at step 1023 : 1.1125369292536007e-308
# underflow at step 1024 : 5.562684646268003e-309
# Overflow error
# Max exponent of 2**(-i) before underflow: i =  1023
#
# Corresponding number:  1.1125369292536007e-308

# %% [markdown]
# 4\. Write a program to determine the machine precision
#
# **Tips**: define a new variable by adding a smaller and smaller value (proceeding similarly to prob. 2) to an original variable and check the point where the two are the same

# %%
# inizialization of variables used in the while loop
exp = 1.
x = 1.
y = 0.5
precision = 2**(-exp)

while(x != y and precision < 2000):
    precision = 2**(-exp)
    y = x
    x += precision
    exp += 1

print('Machine precision : ', precision, ' equal to 2**(-{})'.format(int(exp)))
# Out:
# Machine precision :  5.551115123125783e-17  equal to 2**(-55)

# %% [markdown]
# 5\. Write a function that takes in input three parameters $a$, $b$ and $c$ and prints out the two solutions to the quadratic equation $ax^2+bx+c=0$ using the standard formula:
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# (a) use the program to compute the solution for $a=0.001$, $b=1000$ and $c=0.001$
#
# (b) re-express the standard solution formula by multiplying top and bottom by $-b\mp\sqrt{b^2-4ac}$ and again find the solution for $a=0.001$, $b=1000$ and $c=0.001$. How does it compare with what previously obtained? Why?
#
# (c) write a function that compute the roots of a quadratic equation accurately in all cases

# %%
import math

# (a)
def solve_quadratic(a,b,c):
    
    # this is correct
    delta_squared = b**2 - 4*a*c
    print('Delta squared: ', delta_squared )
    
    #check if the square root gives problem
    delta = math.sqrt(b**2 - 4*a*c)
    if delta**2 != delta_squared:
        print('Approximation: (sqrt(delta))**2 - delta_squared =', delta**2 - delta_squared)
    
    diff_numerator = -b + math.sqrt(b**2 - 4*a*c)
    if diff_numerator + b != delta:
        print('First numerator: ', diff_numerator  )
    
    x1 = ( -b + math.sqrt(b**2 - 4*a*c) )/ (2*a)
    
    sum_numerator = -b - math.sqrt(b**2 - 4*a*c)
    if sum_numerator + b != - delta:
        print('Second numerator: ', sum_numerator  )
        
    x2 =  (-b - math.sqrt(b**2 - 4*a*c) )/ (2*a)
    return x1, x2

# (b)
def solve_quadratic2(a,b,c):
    x1 = 2*c / (-b - math.sqrt(b**2 - 4*a*c))
    x2 =  2*c / (-b + math.sqrt(b**2 - 4*a*c))
    return x1, x2

def solve_quadratic3(a,b,c):
    x1 = 2*c / (-b - math.sqrt(b**2 - 4*a*c))
    x2 =  (-b - math.sqrt(b**2 - 4*a*c) )/ (2*a)
    return x1, x2

def solve_quadratic4(a,b,c):
    x2 = 2*c / (-b + math.sqrt(b**2 - 4*a*c))
    x1 =  (-b + math.sqrt(b**2 - 4*a*c) )/ (2*a)
    return x1, x2
    
a = 0.001
b = 1000
c = 0.001

print('Results with first method: ', solve_quadratic(a,b,c), '\n')
print('Results with second method: ', solve_quadratic2(a,b,c), '\n')
print('Results with third method: ',solve_quadratic3(a,b,c), '\n')
print('Results with fourth method: ',solve_quadratic4(a,b,c), '\n')

a = 1
b = 1000000
c = 1

print('Results with first method: ', solve_quadratic(a,b,c), '\n')
print('Results with second method: ', solve_quadratic2(a,b,c), '\n')
print('Results with third method: ',solve_quadratic3(a,b,c), '\n')
print('Results with fourth method: ',solve_quadratic4(a,b,c), '\n')
# Out:
# Delta squared:  999999.999996
# Approximation: (sqrt(delta))**2 - delta_squared = 1.1641532182693481e-10
# Results with first method:  (-9.999894245993346e-07, -999999.999999)
#
# Results with second method:  (-1.000000000001e-06, -1000010.5755125057)
#
# Results with third method:  (-1.000000000001e-06, -999999.999999)
#
# Results with fourth method:  (-9.999894245993346e-07, -1000010.5755125057)
#
# Delta squared:  999999999996
# Results with first method:  (-1.00000761449337e-06, -999999.999999)
#
# Results with second method:  (-1.000000000001e-06, -999992.38556461)
#
# Results with third method:  (-1.000000000001e-06, -999999.999999)
#
# Results with fourth method:  (-1.00000761449337e-06, -999992.38556461)

# %% [markdown]
# The correct one is solve_quadratic3, where in both the solutions is used the term $-b -\sqrt{b^2 - 4ac}$

# %% [markdown]
# 6\. Write a program that implements the function $f(x)=x(x−1)$
#
# (a) Calculate the derivative of the function at the point $x = 1$ using the derivative definition:
#
# $$
# \frac{{\rm d}f}{{\rm d}x} = \lim_{\delta\to0} \frac{f(x+\delta)-f(x)}{\delta}
# $$
#
# with $\delta = 10^{−2}$. Calculate the true value of the same derivative analytically and compare with the answer your program gives. The two will not agree perfectly. Why not?
#
# (b) Repeat the calculation for $\delta = 10^{−4}, 10^{−6}, 10^{−8}, 10^{−10}, 10^{−12}$ and $10^{−14}$. How does the accuracy scales with $\delta$?

# %%
def f1(x):
    return x*(x-1)

def f2(x):
    return x**2 - x

def derivative(f, x, delta):
    derivative = ( f(x+delta) - f(x) ) / delta
    return derivative

deltas = [1e-02, 1e-04, 1e-06, 1e-08, 1e-10, 1e-12, 1e-14]

for delta in deltas:
    print('Delta = ', delta)
    print('x(x-1) result: ', derivative(f1,1,delta))
    print('x**2 - x result: ', derivative(f2,1,delta))
    print('x(x-1) accuracy: ', derivative(f1,1,delta) - 1)
    print('x**2 - x accuracy: ', derivative(f2,1,delta) - 1, '\n')
# Out:
# Delta =  0.01
# x(x-1) result:  1.010000000000001
# x**2 - x result:  1.0099999999999998
# x(x-1) accuracy:  0.010000000000000897
# x**2 - x accuracy:  0.009999999999999787
#
# Delta =  0.0001
# x(x-1) result:  1.0000999999998899
# x**2 - x result:  1.0000999999992821
# x(x-1) accuracy:  9.999999988985486e-05
# x**2 - x accuracy:  9.999999928211878e-05
#
# Delta =  1e-06
# x(x-1) result:  1.0000009999177333
# x**2 - x result:  1.000001000006634
# x(x-1) accuracy:  9.99917733279787e-07
# x**2 - x accuracy:  1.0000066339443947e-06
#
# Delta =  1e-08
# x(x-1) result:  1.0000000039225287
# x**2 - x result:  0.999999993922529
# x(x-1) accuracy:  3.922528746258536e-09
# x**2 - x accuracy:  -6.07747097092215e-09
#
# Delta =  1e-10
# x(x-1) result:  1.000000082840371
# x**2 - x result:  1.000000082740371
# x(x-1) accuracy:  8.284037100736441e-08
# x**2 - x accuracy:  8.274037099909037e-08
#
# Delta =  1e-12
# x(x-1) result:  1.0000889005833413
# x**2 - x result:  1.000088900582341
# x(x-1) accuracy:  8.890058334132256e-05
# x**2 - x accuracy:  8.890058234101161e-05
#
# Delta =  1e-14
# x(x-1) result:  0.9992007221626509
# x**2 - x result:  0.9992007221626409
# x(x-1) accuracy:  -0.0007992778373491216
# x**2 - x accuracy:  -0.0007992778373591136

# %% [markdown]
# Accuracy initially increases with smaller deltas, but after $10^{-8}$ the accuracy starts to decrease.

# %% [markdown]
# 7\. Consider the integral of the semicircle of radius 1:
# $$
# I=\int_{-1}^{1} \sqrt(1-x^2) {\rm d}x
# $$
# which it's known to be $I=\frac{\pi}{2}=1.57079632679...$.
# Alternatively we can use the Riemann definition of the integral:
# $$
# I=\lim_{N\to\infty} \sum_{k=1}^{N} h y_k
# $$
#
# with $h=2/N$ the width of each of the $N$ slices the domain is divided into and where
# $y_k$ is the value of the function at the $k-$th slice.
#
# (a) Write a programe to compute the integral with $N=100$. How does the result compares to the true value?
#
# (b) How much can $N$ be increased if the computation needs to be run in less than a second? What is the gain in running it for 1 minute?

# %%
import math

def f(x):
    return math.sqrt(1 - x**2)

def integral(N):
    I = 0
    h = 2/N
    for i in range(1,N):
        I += h*f(-1 + h*(i+1/2))
    return I

N = 100
print(integral(100))
# Out:
# 1.5684614290338625

# %%
Ns = [10**i for i in range(2,10)]

Is = []
for N in Ns:
    Is.append(math.pi/2 - integral(N))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(Ns, Is)
plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.xlabel('N [logscale]')
plt.ylabel('pi/2 - I(N) [logscale]')
plt.show()

# %%
for N in Ns[:7]:
    print('Time for N = {}'.format(N))
    # %timeit integral(N)
# Out:
# Time for N = 100
# 42.8 µs ± 518 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# Time for N = 1000
# 479 µs ± 5.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Time for N = 10000
# 5.06 ms ± 31.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Time for N = 100000
# 53 ms ± 1.05 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Time for N = 1000000
# 514 ms ± 4.81 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Time for N = 10000000
# 5.3 s ± 152 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Time for N = 100000000
# 54.3 s ± 2.2 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# For my CPU:
# * N = 100 -> absolute error of order $10^{-3}$
# * N = $10^6$ for times under 1 second -> absolute error of order $10^{-9}$
# * N = $10^8$ for times under 1 minute -> absolute error of order $10^{-11}$
