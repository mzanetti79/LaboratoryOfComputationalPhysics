# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that they are two procedure yields to same result
# * What percent of the total variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
import numpy as np
from scipy import linalg as la
from matplotlib import pyplot as plt

v = np.zeros((3,1000))
mu , sigma1, sigma2 = 0, 1, 3
s1 = np.random.normal(mu,sigma1,1000)
s2 = np.random.normal(mu,sigma2,1000)

v[0]=s1
v[1]=v[0]+s2
v[2]=2*v[0]+v[1]

eigenvalues, eigenvectors = la.eig(np.cov(v))
print ("Eigenvalues : ",eigenvalues,'\n')
print ("Eigenvectors: ",eigenvectors,'\n')

print(np.dot(eigenvectors,np.dot(np.diag(eigenvalues), la.inv(eigenvectors))),'\n')

U, spectrum, Vt = la.svd(np.cov(v))

print("shapes:", U.shape,  spectrum.shape, Vt.shape)

print (spectrum,'\n')
print (U,'\n')
print (Vt,'\n')

D = np.zeros((3, 3))
for i in range(min(3, 3)):
    D[i, i] = spectrum[i]
SVD = np.dot(U, np.dot(D, Vt))
print (SVD)
l, V = np.linalg.eig(np.cov(v))
print (V)
Lambda=np.diag(l)
print (Lambda)
print ("A.trace():", np.cov(v).trace())
print ("Lambda.trace():", Lambda.trace())

print ((Lambda[0,0])/Lambda.trace())
print ((Lambda[1,1])/Lambda.trace())
print ((Lambda[2,2])/Lambda.trace())

newv = np.dot(V.T,v)

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))
axes[0,0].scatter(v[0],v[1])
axes[0,1].scatter(v[0],v[2])
axes[0,2].scatter(v[1],v[2])
axes[1,0].scatter(newv[0],newv[1])
axes[1,1].scatter(newv[0],newv[2])
axes[1,2].scatter(newv[1],newv[2])
# Out:
# Eigenvalues :  [ 2.78513329e+01+0.j -3.05359158e-16+0.j  2.11093644e+00+0.j]
#
# Eigenvectors:  [[-0.11812052 -0.81649658  0.56513793]
#  [-0.57402926 -0.40824829 -0.70980543]
#  [-0.8102703   0.40824829  0.42047042]]
#
# [[ 1.06278727+0.j  1.04167271+0.j  3.16724725+0.j]
#  [ 1.04167271+0.j 10.24082107+0.j 12.32416648+0.j]
#  [ 3.16724725+0.j 12.32416648+0.j 18.65866097+0.j]]
#
# shapes: (3, 3) (3,) (3, 3)
# [2.78513329e+01 2.11093644e+00 7.81009902e-16]
#
# [[-0.11812052  0.56513793 -0.81649658]
#  [-0.57402926 -0.70980543 -0.40824829]
#  [-0.8102703   0.42047042  0.40824829]]
#
# [[-0.11812052 -0.57402926 -0.8102703 ]
#  [ 0.56513793 -0.70980543  0.42047042]
#  [ 0.81649658  0.40824829 -0.40824829]]
#
# [[ 1.06278727  1.04167271  3.16724725]
#  [ 1.04167271 10.24082107 12.32416648]
#  [ 3.16724725 12.32416648 18.65866097]]
# [[-0.11812052 -0.81649658  0.56513793]
#  [-0.57402926 -0.40824829 -0.70980543]
#  [-0.8102703   0.40824829  0.42047042]]
# ...

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
n, p = 1000, 3
v = np.zeros((3,1000))
mu , sigma1, sigma2, sigma3, sigma4 = 0, 1, 3, 0.2, 0.6
s1 = np.random.normal(mu,sigma1,1000)
for i in range(10):
    noise = np.random.normal(mu, sigma3)
    s1 = s1+noise
s2 = np.random.normal(mu,sigma2,1000)
for i in range(10):
    noise2 = np.random.normal(mu,sigma4)
    s2 = s2+noise2

v[0]=s1
v[1]=v[0]+s2
v[2]=2*v[0]+v[1]
np.cov(v)

eigenvalues, eigenvectors = la.eig(np.cov(v))
print ("Eigenvalues : ",eigenvalues,'\n')
print ("Eigenvectors: ",eigenvectors,'\n')

print(np.dot(eigenvectors,np.dot(np.diag(eigenvalues), la.inv(eigenvectors))),'\n')

U, spectrum, Vt = la.svd(np.cov(v))

print("shapes:", U.shape,  spectrum.shape, Vt.shape)

print (spectrum,'\n')
print (U,'\n')
print (Vt,'\n')

D = np.zeros((3, 3))
for i in range(min(3, 3)):
    D[i, i] = spectrum[i]
SVD = np.dot(U, np.dot(D, Vt))
print (SVD)
l, V = np.linalg.eig(np.cov(v))
print (V)
Lambda=np.diag(l)
print (Lambda)
print ("A.trace():", np.cov(v).trace())
print ("Lambda.trace():", Lambda.trace())

print ((Lambda[0,0])/Lambda.trace())
print ((Lambda[1,1])/Lambda.trace())
print ((Lambda[2,2])/Lambda.trace())

newv = np.dot(V.T,v)

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))
axes[0,0].scatter(v[0],v[1])
axes[0,1].scatter(v[0],v[2])
axes[0,2].scatter(v[1],v[2])
axes[1,0].scatter(newv[0],newv[1])
axes[1,1].scatter(newv[0],newv[2])
axes[1,2].scatter(newv[1],newv[2])
# Out:
# Eigenvalues :  [2.61088331e+01+0.j 7.83730476e-17+0.j 1.95858788e+00+0.j]
#
# Eigenvectors:  [[-0.11772599 -0.81649658  0.56522024]
#  [-0.5745246  -0.40824829 -0.70940455]
#  [-0.80997659  0.40824829  0.42103594]]
#
# [[ 0.98757077+0.j  0.98057494+0.j  2.95571648+0.j]
#  [ 0.98057494+0.j  9.60363368+0.j 11.56478357+0.j]
#  [ 2.95571648+0.j 11.56478357+0.j 17.47621653+0.j]]
#
# shapes: (3, 3) (3,) (3, 3)
# [2.61088331e+01 1.95858788e+00 3.05298933e-16]
#
# [[-0.11772599  0.56522024 -0.81649658]
#  [-0.5745246  -0.70940455 -0.40824829]
#  [-0.80997659  0.42103594  0.40824829]]
#
# [[-0.11772599 -0.5745246  -0.80997659]
#  [ 0.56522024 -0.70940455  0.42103594]
#  [-0.81649658 -0.40824829  0.40824829]]
#
# [[ 0.98757077  0.98057494  2.95571648]
#  [ 0.98057494  9.60363368 11.56478357]
#  [ 2.95571648 11.56478357 17.47621653]]
# [[-0.11772599 -0.81649658  0.56522024]
#  [-0.5745246  -0.40824829 -0.70940455]
#  [-0.80997659  0.40824829  0.42103594]]
# ...

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset
